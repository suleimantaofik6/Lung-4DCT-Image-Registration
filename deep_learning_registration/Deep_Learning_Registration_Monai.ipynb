# %% [markdown]
# ## MONAI deep learning affine registration of CT images with landmarks
#
# ### Team members
# 1. Taofik Ahmed Suleiman
# 2. Daniel Tweneboah Anyimadu
#
# ##### This project has been achieved in three key pipelines, aside adopting the preprocessing and data convertion already done in the ElastixImplentation.ipynb:
# 1. MONAI deep learning registration data preparation and loading
# 2. Monai deep learning registration setup - Defining hyperparameters and loss function
# 3. Models training and prediction - we have trained the following models:
#
#     SegResNet
#
#     VNet
#
#     Autoencoder
#
#     HighResNet

# %% [markdown]
# Install the needed monai packages

# %%
#!python -c "import monai" || pip install -q "monai-weekly[nibabel, tqdm]"
#!python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline
# Out:
# c:\Users\sulei\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\sulei\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# c:\Users\sulei\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# import the libraries 
import os
import glob
import json
import time
import tempfile
import warnings
from pprint import pprint
import pandas as pd



# data science imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# PyTorch imports
import torch
import torch.nn.functional as F
from torch.nn import MSELoss
from torch.utils.tensorboard import SummaryWriter

# MONAI imports
from monai.apps import download_and_extract
from monai.data import Dataset, CacheDataset, DataLoader
from monai.data.utils import list_data_collate
from monai.losses import BendingEnergyLoss

import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR

from monai.metrics import DiceMetric
from monai.networks.blocks import Warp
from monai.networks.nets import SegResNet
from monai.utils import set_determinism, first
from monai.config import print_config
from monai.transforms import (
    Compose,
    LoadImaged,
    MapTransform,
    RandAffined,
    Resized,
    ScaleIntensityRanged,
)

set_determinism(seed=0)
torch.backends.cudnn.benchmark = True
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
# set data directory 

directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# C:\Users\sulei\AppData\Local\Temp\tmp2ak8g11x

# %% [markdown]
# ### 1. MONAI deep learning registration data preparation and loading affine transforms
#
# We created classes to transform the keypoints, and defined several function all found in the monai_utils.py.
#
#
# Steps:
# 1. get_files Function: This function is used to prepare the files in the correct order, it processes the fixed and moving images with their landmarks.
# 2. LoadKeypoints, and TransformKeypoints classes: since Monai are different for images, we need to define a customized transform to handle our landmarks.
# 3. Apply these clases to build a tranform pipelines for the training and validation process
# 4. Visualization

# %%
# file directory
data_dir = r'C:\Users\sulei\Downloads\MAIA Girona\MIRA\Project\train12\deepL'

def get_files(data_dir):
    """
    Get files for image registration, using one out of every four samples as val set
    """
    file_list = os.listdir(data_dir)
    # Get a list of all files in the input directory
    file_list = [f for f in os.listdir(data_dir) if f.endswith('_eBHCT.nii')]

    data = {"training_paired_images": [], "registration_val": []}

    for i, moving_image_name in enumerate(file_list):
        # Extract case name from the moving image name
        case_name = moving_image_name.split('_')[0]

        # Construct the file paths for fixed and moving images
        fixed_image_path = os.path.join(data_dir, f"{case_name}_iBHCT.nii")
        moving_image_path = os.path.join(data_dir, f"{case_name}_eBHCT.nii")

        # Construct the file paths for fixed and moving landmarks
        fixed_landmark_path = os.path.join(data_dir, f"{case_name}_300_iBH_xyz_r1.txt")
        moving_landmark_path = os.path.join(data_dir, f"{case_name}_300_eBH_xyz_r1.txt")

        # Create a dictionary for each pair of fixed and moving images with landmarks
        pair = {
            "fixed_image": fixed_image_path,
            "moving_image": moving_image_path,
            "fixed_landmarks": fixed_landmark_path,
            "moving_landmarks": moving_landmark_path,
        }

        if i % 4 == 3:
            # Use one out of every four samples as val set
            data["registration_val"].append(pair)
        else:
            data["training_paired_images"].append(pair)

    return data


# Get the file information
file_info = get_files(data_dir)

pprint(file_info["training_paired_images"])
pprint(file_info["registration_val"])
# Out:
# [{'fixed_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                  'Girona\\MIRA\\Project\\train12\\deepL\\copd1_iBHCT.nii',
#   'fixed_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                      'Girona\\MIRA\\Project\\train12\\deepL\\copd1_300_iBH_xyz_r1.txt',
#   'moving_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                   'Girona\\MIRA\\Project\\train12\\deepL\\copd1_eBHCT.nii',
#   'moving_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                       'Girona\\MIRA\\Project\\train12\\deepL\\copd1_300_eBH_xyz_r1.txt'},
#  {'fixed_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                  'Girona\\MIRA\\Project\\train12\\deepL\\copd2_iBHCT.nii',
#   'fixed_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                      'Girona\\MIRA\\Project\\train12\\deepL\\copd2_300_iBH_xyz_r1.txt',
#   'moving_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                   'Girona\\MIRA\\Project\\train12\\deepL\\copd2_eBHCT.nii',
#   'moving_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                       'Girona\\MIRA\\Project\\train12\\deepL\\copd2_300_eBH_xyz_r1.txt'},
#  {'fixed_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                  'Girona\\MIRA\\Project\\train12\\deepL\\copd3_iBHCT.nii',
#   'fixed_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                      'Girona\\MIRA\\Project\\train12\\deepL\\copd3_300_iBH_xyz_r1.txt',
#   'moving_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                   'Girona\\MIRA\\Project\\train12\\deepL\\copd3_eBHCT.nii',
#   'moving_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                       'Girona\\MIRA\\Project\\train12\\deepL\\copd3_300_eBH_xyz_r1.txt'}]
# [{'fixed_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                  'Girona\\MIRA\\Project\\train12\\deepL\\copd4_iBHCT.nii',
#   'fixed_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                      'Girona\\MIRA\\Project\\train12\\deepL\\copd4_300_iBH_xyz_r1.txt',
#   'moving_image': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                   'Girona\\MIRA\\Project\\train12\\deepL\\copd4_eBHCT.nii',
#   'moving_landmarks': 'C:\\Users\\sulei\\Downloads\\MAIA '
#                       'Girona\\MIRA\\Project\\train12\\deepL\\copd4_300_eBH_xyz_r1.txt'}]

# %% [markdown]
# Customized transforms for the landmarks

# %%
class LoadKeypoints(MapTransform):
    """
    Load keypoints from TXT file
    """

    def __init__(self, keys_fixed_landmarks, keys_moving_landmarks):
        super().__init__(keys_fixed_landmarks + keys_moving_landmarks)
        self.keys_fixed_landmarks = keys_fixed_landmarks
        self.keys_moving_landmarks = keys_moving_landmarks

    def __call__(self, data):
        d = dict(data)
        
        for key_fixed, key_moving in zip(self.keys_fixed_landmarks, self.keys_moving_landmarks):
            # Load keypoints from TXT file
            keypoints_fixed = np.loadtxt(d[key_fixed])
            keypoints_moving = np.loadtxt(d[key_moving])

            # Convert to torch tensor
            keypoints_fixed = torch.as_tensor(keypoints_fixed)
            keypoints_moving = torch.as_tensor(keypoints_moving)

            # Update data dictionary
            d[key_fixed] = keypoints_fixed  # [N, 3]
            d[key_moving] = keypoints_moving  # [N, 3]

        return d
    
class TransformKeypoints(MapTransform):
    """
    Applies any potential linear image transformation to keypoint values
    """

    def __init__(self, keys_fixed_landmarks, keys_moving_landmarks, keys_fixed_images, keys_moving_images, ras=False):
        super().__init__(keys_fixed_landmarks + keys_moving_landmarks + keys_fixed_images + keys_moving_images)
        self.keys_fixed_landmarks = keys_fixed_landmarks
        self.keys_moving_landmarks = keys_moving_landmarks
        self.keys_fixed_images = keys_fixed_images
        self.keys_moving_images = keys_moving_images
        self.ras = ras

    def __call__(self, data):
        d = dict(data)

        for kf, km, fi, mi in zip(self.keys_fixed_landmarks, self.keys_moving_landmarks, self.keys_fixed_images, self.keys_moving_images):
            # Get image meta data
            image_fixed = d[fi]
            image_moving = d[mi]
            meta_fixed = image_fixed.meta
            meta_moving = image_moving.meta

            # Get keypoints
            keypoints_fixed_ijk = d[kf]
            keypoints_moving_ijk = d[km]

            # Get transformation (in voxel space)
            affine_fixed = meta_fixed["affine"]
            original_affine_fixed = torch.as_tensor(meta_fixed["original_affine"], dtype=affine_fixed.dtype, device=affine_fixed.device)
            transforms_affine_fixed = original_affine_fixed.inverse() @ affine_fixed
            transforms_affine_fixed = transforms_affine_fixed.inverse()

            affine_moving = meta_moving["affine"]
            original_affine_moving = torch.as_tensor(meta_moving["original_affine"], dtype=affine_moving.dtype, device=affine_moving.device)
            transforms_affine_moving = original_affine_moving.inverse() @ affine_moving
            transforms_affine_moving = transforms_affine_moving.inverse()

            if self.ras:
                # RAS space
                transforms_affine_fixed = original_affine_fixed @ transforms_affine_fixed
                transforms_affine_moving = original_affine_moving @ transforms_affine_moving

            # Apply transformation to keypoints
            keypoints_fixed_ijk_moved = torch.cat((keypoints_fixed_ijk, torch.ones((keypoints_fixed_ijk.shape[0], 1))), dim=1)
            keypoints_fixed_ijk_moved = (transforms_affine_fixed @ keypoints_fixed_ijk_moved.T).T
            keypoints_fixed_ijk_moved = keypoints_fixed_ijk_moved[:, :3]
            keypoints_fixed_ijk_moved = keypoints_fixed_ijk_moved.float()

            keypoints_moving_ijk_moved = torch.cat((keypoints_moving_ijk, torch.ones((keypoints_moving_ijk.shape[0], 1))), dim=1)
            keypoints_moving_ijk_moved = (transforms_affine_moving @ keypoints_moving_ijk_moved.T).T
            keypoints_moving_ijk_moved = keypoints_moving_ijk_moved[:, :3]
            keypoints_moving_ijk_moved = keypoints_moving_ijk_moved.float()

            d[kf] = keypoints_fixed_ijk_moved  # [N, 3]
            d[km] = keypoints_moving_ijk_moved  # [N, 3]

        return d

# %% [markdown]
# Tranform pipelines for our training and validation - Here we applied our customized landmark classes and also reduced our image resolution

# %%
full_res_training = False

if full_res_training:
    target_res = [224, 192, 224]
    spatial_size = [-1, -1, -1]
else:
    target_res = [96, 96, 96]
    spatial_size = target_res

train_transforms = Compose(
    [
        LoadImaged(keys=["fixed_image", "moving_image"], ensure_channel_first=True),
        LoadKeypoints(keys_fixed_landmarks=["fixed_landmarks"], keys_moving_landmarks=["moving_landmarks"]),
        ScaleIntensityRanged(
            keys=["fixed_image", "moving_image"],
            a_min=-1200,
            a_max=400,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        Resized(
            keys=["fixed_image", "moving_image"],
            mode=("trilinear", "trilinear"),
            align_corners=(True, True),
            spatial_size=spatial_size,
        ),
        RandAffined(
            keys=["fixed_image", "moving_image"],
            mode=("bilinear", "bilinear"),
            prob=0.8,
            shear_range=0.2,
            translate_range=int(25 * target_res[0] / 224),
            rotate_range=np.pi / 180 * 15,
            scale_range=0.2,
            padding_mode=("zeros", "zeros"),
        ),
        TransformKeypoints(
            keys_fixed_landmarks=["fixed_landmarks"],
            keys_moving_landmarks=["moving_landmarks"],
            keys_fixed_images=["fixed_image"],
            keys_moving_images=["moving_image"],
        ),
    ]
)

val_transforms = Compose(
    [
        LoadImaged(keys=["fixed_image", "moving_image"], ensure_channel_first=True),
        ScaleIntensityRanged(
            keys=["fixed_image", "moving_image"],
            a_min=-1200,
            a_max=400,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        Resized(
            keys=["fixed_image", "moving_image"],
            mode=("trilinear", "trilinear"),
            align_corners=(True, True),
            spatial_size=spatial_size,
        ),
        LoadKeypoints(keys_fixed_landmarks=["fixed_landmarks"], keys_moving_landmarks=["moving_landmarks"]),
        TransformKeypoints(
            keys_fixed_landmarks=["fixed_landmarks"],
            keys_moving_landmarks=["moving_landmarks"],
            keys_fixed_images=["fixed_image"],
            keys_moving_images=["moving_image"],
        ),
    ]
)

# %% [markdown]
# Apply Monai DataLoader and visualize the results for sanity check

# %%
# Assuming you have already defined `file_info` and `train_transforms` as in your previous code
train_files = file_info["training_paired_images"]
val_files = file_info["registration_val"]

# Create datasets and loaders for both training and validation
train_ds = Dataset(data=train_files, transform=train_transforms)
val_ds = Dataset(data=val_files, transform=train_transforms)

train_loader = DataLoader(train_ds, batch_size=1, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=True)

# Function to visualize images and point clouds
def visualize_sample(axs, image, title):
    slice_idx = int(target_res[0] * 95.0 / 224)
    axs.imshow(image[:, :, slice_idx], cmap="bone", origin="lower")
    axs.set_title(title)
    axs.set_axis_off()

def visualize_pointcloud(ax, points, color):
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], s=10.0, marker="o", color=color)
    ax.view_init(-10, 80)
    ax.set_aspect("auto")
    ax.set_title("Pointcloud Visualizations")

# Visualize samples from the training set
for i, train_data in enumerate(train_loader):
    fixed_image_train = train_data["fixed_image"][0][0].permute(1, 0, 2)
    moving_image_train = train_data["moving_image"][0][0].permute(1, 0, 2)
    fixed_points_train = train_data["fixed_landmarks"][0]
    moving_points_train = train_data["moving_landmarks"][0]

    # Plot images
    fig_train, axs_train = plt.subplots(1, 2)
    visualize_sample(axs_train[0], fixed_image_train, "Fixed Image (Train)")
    visualize_sample(axs_train[1], moving_image_train, "Moving Image (Train)")
    plt.show()

    # Plot point clouds
    fig_pc_train = plt.figure()
    ax_pc_train = fig_pc_train.add_subplot(projection="3d")
    visualize_pointcloud(ax_pc_train, fixed_points_train, "blue")
    visualize_pointcloud(ax_pc_train, moving_points_train, "red")
    plt.show()

    if i == 2:  # Visualize only a few samples from the training set for brevity
        break

# Visualize samples from the validation set
for i, val_data in enumerate(val_loader):
    fixed_image_val = val_data["fixed_image"][0][0].permute(1, 0, 2)
    moving_image_val = val_data["moving_image"][0][0].permute(1, 0, 2)
    fixed_points_val = val_data["fixed_landmarks"][0]
    moving_points_val = val_data["moving_landmarks"][0]

    # Plot images
    fig_val, axs_val = plt.subplots(1, 2)
    visualize_sample(axs_val[0], fixed_image_val, "Fixed Image (Validation)")
    visualize_sample(axs_val[1], moving_image_val, "Moving Image (Validation)")
    plt.show()

    # Plot point clouds
    fig_pc_val = plt.figure()
    ax_pc_val = fig_pc_val.add_subplot(projection="3d")
    visualize_pointcloud(ax_pc_val, fixed_points_val, "blue")
    visualize_pointcloud(ax_pc_val, moving_points_val, "red")
    plt.show()

    if i == 0:  # Visualize only one sample from the validation set for brevity
        break

# %% [markdown]
# ### 2. Monai deep learning registration setup - Defining hyperparameters and loss function
#
# We created several function to achieve this step as highlighted below:
#
#
# Steps:
# 1. Hyperparameter: The hyperparameters are set in a way to allow the optimization to be driven only by TRE loss since we are interested in points.
# 2. Model Forward Pass: The forward function is responsible for the forward pass of the model. It predicts the Displacement Field (DDF) and warps the moving image based on the predicted DDF.
# 3. Collate Function: This ensures that keypoints are aligned for easy collation during batch processing.
# 4. Target Registration Error (TRE) Calculation: The tre function computes the TRE loss between fixed and moving landmarks.
# 5. Loss Function: The loss_fun function defines the multi-target loss used for the model optimization. It includes components for TRE, MSE, and Bending Energy.

# %% [markdown]
# Set hyperparameters

# %%
batch_size = 1
lr = 1e-4
weight_decay = 1e-5
max_epochs = 50

# Image voxel size at target resolution
vx = np.array([1.5, 1.5, 1.5]) / (np.array(target_res) / np.array([224, 192, 224]))
# vx = [0.6, 0.6, 2.5]

# Loss weights (set to zero to disable loss term)
lam_t = 1e0  # TRE (keypoint loss)
lam_m = 0    # MSE
lam_r = 0    # Bending loss 

# Write model and tensorboard logs
do_save = True
dir_save = os.path.join(os.getcwd(), "models", "500")
if do_save and not os.path.exists(dir_save):
    os.makedirs(dir_save)

# %% [markdown]
# Customazed function for forward, collate, tre and loss fun

# %%
def forward(fixed_image, moving_image, fixed_landmarks, model, warp_layer):
    """
    Model forward pass: predict DDF, warp moving images
    """
    batch_size = fixed_image.shape[0]

    # predict DDF through your model
    ddf_image = model(torch.cat((moving_image, fixed_image), dim=1)).float()

    # warp moving image with the predicted ddf
    pred_image = warp_layer(moving_image, ddf_image)

    # warp vectors for keypoints (optional)
    ddf_keypoints = None
    if fixed_landmarks is not None:
        with torch.no_grad():
            offset = torch.as_tensor(fixed_image.shape[-3:]).to(fixed_landmarks.device) / 2
            offset = offset[None][None]
            ddf_keypoints = torch.flip((fixed_landmarks - offset) / offset, (-1,))
        ddf_keypoints = (
            F.grid_sample(ddf_image, ddf_keypoints.view(batch_size, -1, 1, 1, 3))
            .view(batch_size, 3, -1)
            .permute((0, 2, 1))
        )

    return ddf_image, ddf_keypoints, pred_image


def collate_fn(batch):
    """
    Custom collate function.
    Aligns keypoints for easy collation.
    """
    max_length = 0
    for data in batch:
        length = data["fixed_landmarks"].shape[0]
        if length > max_length:
            max_length = length

    for data in batch:
        length = data["fixed_landmarks"].shape[0]
        data["fixed_landmarks"] = torch.cat(
            (data["fixed_landmarks"], float("nan") * torch.ones((max_length - length, 3))), dim=0
        )
        data["moving_landmarks"] = torch.cat(
            (data["moving_landmarks"], float("nan") * torch.ones((max_length - length, 3))), dim=0
        )

    return {
        "fixed_image": torch.stack([data["fixed_image"] for data in batch]),
        "moving_image": torch.stack([data["moving_image"] for data in batch]),
        "fixed_landmarks": torch.stack([data["fixed_landmarks"] for data in batch]),
        "moving_landmarks": torch.stack([data["moving_landmarks"] for data in batch]),
        # Add other keys if needed
    }

# %%
def tre(fixed, moving, vx=None):
    """
    Computes target registration error (TRE) loss for keypoint matching.
    """
    if vx is None:
        return ((fixed - moving) ** 2).sum(-1).sqrt().mean()
    else:
        vx_tensor = torch.tensor(vx, dtype=fixed.dtype, device=fixed.device)
        return (((fixed - moving) * vx_tensor) ** 2).sum(-1).sqrt().mean()
    



def loss_fun(
    fixed_image,
    pred_image,
    fixed_landmarks,
    pred_landmarks,
    ddf_image,
    lam_t,
    lam_m,
    lam_r,
):
    """
    Custom multi-target loss:
        - TRE as the main loss component
        - Parametrizable weights for further (optional) components: MSE/BendingEnergy
    Note: Might require "calibration" of lambda weights for the multi-target components,
        e.g., by making a first trial run and manually setting weights to account for different magnitudes
    """
    # Instantiate where necessary
    if lam_m > 0:
        mse_loss = MSELoss()
    if lam_r > 0:
        regularization = BendingEnergyLoss()

    # Compute loss components
    t = tre(fixed_landmarks, pred_landmarks) if lam_t > 0 else 0.0
    m = mse_loss(fixed_image, pred_image) if lam_m > 0 else 0.0
    r = regularization(ddf_image) if lam_r > 0 else 0.0

    # Weighted combination
    return lam_t * t + lam_m * m + lam_r * r

# %%
train_files = file_info["training_paired_images"]
val_files = file_info["registration_val"]

# Cached datasets for high performance during batch generation
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=0)
val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=0)

# DataLoaders, now with a custom function `collate_fn`, to rectify the ragged keypoint tensors
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, collate_fn=collate_fn)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=collate_fn)
# Out:
# Loading dataset:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading dataset: 100%|██████████| 3/3 [00:05<00:00,  2.00s/it]
# Loading dataset: 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]

# %% [markdown]
# ### 3. Model training and prediction
#
# We trained the following models using the steps highlighted below
#
#     - SegResNet
#
#     - VNet
#
#     - Autoencoder
#
#     - HighResNet
#
#
# Steps:
# 1. Model initialization: We used the SegResNet Model, and an optimization set up using Adam optimizer.
# 2. Training and Validation Loop: The training and prediction is carried out here using the TRE as the key loss and best model is saved
# 3. Pretrained Model Loading: At any time, we can load the saved model and perform prediction
# 4. Visualization of final results
# 5. Result compilation

# %% [markdown]
# SegResNet

# %%
# Model
model = SegResNet(
    spatial_dims=3,
    in_channels=2,
    out_channels=3,
    blocks_down=[1, 2, 2, 4],
    blocks_up=[1, 1, 1],
    init_filters=16,
    dropout_prob=0.2,
)
warp_layer = Warp()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=max_epochs)

# %% [markdown]
# Training and Validation process

# %%
# Tensorboard
if do_save:
    writer = SummaryWriter(log_dir=dir_save)

# Training loop
val_interval = 1
best_eval_tre = float("inf")
log_train_loss = []
log_train_tre = []
log_val_tre = []
log_val_loss = []

pth_best_tre, pth_latest = "", ""

for epoch in range(max_epochs):
    # ==============================================
    # Train
    # ==============================================
    t0_train = time.time()
    model.train()

    epoch_loss, n_steps, tre_before, tre_after = 0, 0, 0, 0
    for batch_data in train_loader:
        # Get data
        fixed_image = batch_data["fixed_image"]
        moving_image = batch_data["moving_image"]
        fixed_keypoints = batch_data["fixed_landmarks"]
        moving_keypoints = batch_data["moving_landmarks"]
        n_steps += 1
        # Forward pass and loss
        optimizer.zero_grad()
        ddf_image, ddf_keypoints, pred_image = forward(
            fixed_image, moving_image, fixed_keypoints, model, warp_layer
        )
        loss = loss_fun(
            fixed_image,
            pred_image,
            fixed_keypoints + ddf_keypoints,
            moving_keypoints,
            ddf_image,
            lam_t,
            lam_m,
            lam_r,
        )
        # Optimise
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        # TRE before (voxel space)
        tre_before += tre(fixed_keypoints, moving_keypoints, vx = vx)
        tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx = vx)

    # Scheduler step
    lr_scheduler.step()
    # Loss
    epoch_loss /= n_steps
    tre_before /= n_steps
    tre_after /= n_steps
    log_train_tre.append(tre_after.item())
    log_train_loss.append(epoch_loss)
    if do_save:
        writer.add_scalar("train_loss", epoch_loss, epoch)
    print(f"{epoch + 1} | loss={epoch_loss:.6f}")

    # Mean TRE
    tre_before /= n_steps
    tre_after /= n_steps
    print(
            f"{epoch + 1} | tre_before_train={tre_before:.3f}, tre_after_train={tre_after:.3f}, elapsed time: {time.time()-t0_train:.2f} sec."
    )

    # ==============================================
    # Eval
    # ==============================================
    if (epoch + 1) % val_interval == 0:
        t0_eval = time.time()
        model.eval()

        val_epoch_loss , n_steps, tre_before, tre_after = 0, 0, 0, 0
        with torch.no_grad():
            for batch_data in val_loader:
                # Get data
                fixed_image = batch_data["fixed_image"]
                moving_image = batch_data["moving_image"]
                fixed_keypoints = batch_data["fixed_landmarks"]
                moving_keypoints = batch_data["moving_landmarks"]
                n_steps += 1

                # Infer
                ddf_image, ddf_keypoints, pred_image = forward(
                    fixed_image, moving_image, fixed_keypoints, model, warp_layer
                )

                # Loss for validation
                val_loss = loss_fun(
                    fixed_image,
                    pred_image,
                    fixed_keypoints + ddf_keypoints,
                    moving_keypoints,
                    ddf_image,
                    lam_t,
                    lam_m,
                    lam_r,
                )
                val_epoch_loss += val_loss.item()

                # TRE

                tre_before += tre(fixed_keypoints , moving_keypoints, vx=vx)
                tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx=vx)

        # Mean TRE
        tre_before /= n_steps
        tre_after /= n_steps
        val_epoch_loss /= n_steps
        log_val_loss.append(val_epoch_loss)
        log_val_tre.append(tre_after.item())
        if do_save:
            writer.add_scalar("val_tre", tre_after, epoch)
       

        print(
            f"{epoch + 1} | tre_before_val={tre_before:.3f}, tre_after_val={tre_after:.3f}, elapsed time: {time.time() - t0_train:.2f} sec."
            )


        if tre_after < best_eval_tre:
            best_eval_tre = tre_after
            if do_save:
                # Save best model based on TRE
                if pth_best_tre != "":
                    os.remove(os.path.join(dir_save, pth_best_tre))
                pth_best_tre = f"segresnet_kpt_loss_best_tre_{epoch + 1}_{best_eval_tre:.3f}.pth"
                torch.save(model.state_dict(), os.path.join(dir_save, pth_best_tre))
                print(f"{epoch + 1} | Saving best TRE model: {pth_best_tre}")

        if do_save:
            # Save latest model
            if pth_latest != "":
                os.remove(os.path.join(dir_save, pth_latest))
            pth_latest = "segresnet_kpt_loss_latest.pth"
            torch.save(model.state_dict(), os.path.join(dir_save, pth_latest))
# Out:
# 1 | loss=6.234560
# 1 | tre_before_train=6.507, tre_after_train=6.656, elapsed time: 12.19 sec.
# 1 | tre_before_val=30.364, tre_after_val=30.668, elapsed time: 13.50 sec.
# 1 | Saving best TRE model: segresnet_kpt_loss_best_tre_1_30.668.pth
# 2 | loss=5.782505
# 2 | tre_before_train=6.477, tre_after_train=6.146, elapsed time: 12.19 sec.
# 2 | tre_before_val=30.364, tre_after_val=30.410, elapsed time: 13.46 sec.
# 2 | Saving best TRE model: segresnet_kpt_loss_best_tre_2_30.410.pth
# 3 | loss=5.652596
# 3 | tre_before_train=6.453, tre_after_train=6.032, elapsed time: 12.54 sec.
# 3 | tre_before_val=30.364, tre_after_val=30.260, elapsed time: 14.03 sec.
# 3 | Saving best TRE model: segresnet_kpt_loss_best_tre_3_30.260.pth
# 4 | loss=5.535046
# 4 | tre_before_train=6.471, tre_after_train=5.968, elapsed time: 14.40 sec.
# 4 | tre_before_val=30.364, tre_after_val=30.062, elapsed time: 15.91 sec.
# 4 | Saving best TRE model: segresnet_kpt_loss_best_tre_4_30.062.pth
# 5 | loss=5.297263
# 5 | tre_before_train=6.441, tre_after_train=5.687, elapsed time: 13.70 sec.
# 5 | tre_before_val=30.364, tre_after_val=29.780, elapsed time: 15.04 sec.
# 5 | Saving best TRE model: segresnet_kpt_loss_best_tre_5_29.780.pth
# 6 | loss=5.238927
# 6 | tre_before_train=6.424, tre_after_train=5.645, elapsed time: 12.97 sec.
# 6 | tre_before_val=30.364, tre_after_val=28.820, elapsed time: 14.30 sec.
# 6 | Saving best TRE model: segresnet_kpt_loss_best_tre_6_28.820.pth
# 7 | loss=5.111770
# 7 | tre_before_train=6.450, tre_after_train=5.506, elapsed time: 13.20 sec.
# 7 | tre_before_val=30.364, tre_after_val=28.097, elapsed time: 14.56 sec.
# 7 | Saving best TRE model: segresnet_kpt_loss_best_tre_7_28.097.pth
# 8 | loss=5.149452
# 8 | tre_before_train=6.430, tre_after_train=5.515, elapsed time: 13.02 sec.
# 8 | tre_before_val=30.364, tre_after_val=27.766, elapsed time: 14.39 sec.
# 8 | Saving best TRE model: segresnet_kpt_loss_best_tre_8_27.766.pth
# 9 | loss=5.209357
# 9 | tre_before_train=6.458, tre_after_train=5.573, elapsed time: 13.31 sec.
# 9 | tre_before_val=30.364, tre_after_val=27.676, elapsed time: 14.62 sec.
# 9 | Saving best TRE model: segresnet_kpt_loss_best_tre_9_27.676.pth
# 10 | loss=4.897412
# 10 | tre_before_train=6.441, tre_after_train=5.272, elapsed time: 13.32 sec.
# 10 | tre_before_val=30.364, tre_after_val=27.277, elapsed time: 14.68 sec.
# 10 | Saving best TRE model: segresnet_kpt_loss_best_tre_10_27.277.pth
# 11 | loss=5.036578
# 11 | tre_before_train=6.471, tre_after_train=5.422, elapsed time: 13.15 sec.
# 11 | tre_before_val=30.364, tre_after_val=27.054, elapsed time: 14.49 sec.
# 11 | Saving best TRE model: segresnet_kpt_loss_best_tre_11_27.054.pth
# 12 | loss=4.822299
# 12 | tre_before_train=6.474, tre_after_train=5.190, elapsed time: 12.92 sec.
# 12 | tre_before_val=30.364, tre_after_val=27.293, elapsed time: 14.27 sec.
# 13 | loss=4.945351
# 13 | tre_before_train=6.480, tre_after_train=5.339, elapsed time: 13.07 sec.
# 13 | tre_before_val=30.364, tre_after_val=27.438, elapsed time: 14.51 sec.
# 14 | loss=4.700538
# 14 | tre_before_train=6.443, tre_after_train=5.057, elapsed time: 12.95 sec.
# 14 | tre_before_val=30.364, tre_after_val=26.485, elapsed time: 14.59 sec.
# 14 | Saving best TRE model: segresnet_kpt_loss_best_tre_14_26.485.pth
# 15 | loss=4.677093
# 15 | tre_before_train=6.495, tre_after_train=5.066, elapsed time: 13.00 sec.
# 15 | tre_before_val=30.364, tre_after_val=26.399, elapsed time: 14.51 sec.
# 15 | Saving best TRE model: segresnet_kpt_loss_best_tre_15_26.399.pth
# 16 | loss=4.645657
# 16 | tre_before_train=6.459, tre_after_train=5.016, elapsed time: 12.93 sec.
# 16 | tre_before_val=30.364, tre_after_val=26.363, elapsed time: 14.27 sec.
# 16 | Saving best TRE model: segresnet_kpt_loss_best_tre_16_26.363.pth
# 17 | loss=4.719174
# 17 | tre_before_train=6.473, tre_after_train=5.085, elapsed time: 13.40 sec.
# 17 | tre_before_val=30.364, tre_after_val=26.636, elapsed time: 14.87 sec.
# 18 | loss=4.804605
# 18 | tre_before_train=6.507, tre_after_train=5.186, elapsed time: 13.99 sec.
# 18 | tre_before_val=30.364, tre_after_val=26.644, elapsed time: 15.67 sec.
# 19 | loss=4.407917
# 19 | tre_before_train=6.425, tre_after_train=4.760, elapsed time: 14.76 sec.
# 19 | tre_before_val=30.364, tre_after_val=26.802, elapsed time: 16.24 sec.
# 20 | loss=4.456673
# 20 | tre_before_train=6.425, tre_after_train=4.824, elapsed time: 15.51 sec.
# 20 | tre_before_val=30.364, tre_after_val=26.896, elapsed time: 17.25 sec.
# 21 | loss=4.569433
# 21 | tre_before_train=6.474, tre_after_train=4.962, elapsed time: 16.86 sec.
# 21 | tre_before_val=30.364, tre_after_val=26.838, elapsed time: 18.78 sec.
# 22 | loss=4.516897
# 22 | tre_before_train=6.456, tre_after_train=4.895, elapsed time: 15.48 sec.
# 22 | tre_before_val=30.364, tre_after_val=26.500, elapsed time: 17.42 sec.
# 23 | loss=4.652458
# 23 | tre_before_train=6.484, tre_after_train=5.037, elapsed time: 15.85 sec.
# 23 | tre_before_val=30.364, tre_after_val=26.253, elapsed time: 17.59 sec.
# 23 | Saving best TRE model: segresnet_kpt_loss_best_tre_23_26.253.pth
# 24 | loss=4.775094
# 24 | tre_before_train=6.565, tre_after_train=5.176, elapsed time: 16.45 sec.
# 24 | tre_before_val=30.364, tre_after_val=26.099, elapsed time: 18.23 sec.
# 24 | Saving best TRE model: segresnet_kpt_loss_best_tre_24_26.099.pth
# 25 | loss=4.465410
# 25 | tre_before_train=6.443, tre_after_train=4.812, elapsed time: 16.70 sec.
# 25 | tre_before_val=30.364, tre_after_val=26.049, elapsed time: 18.59 sec.
# 25 | Saving best TRE model: segresnet_kpt_loss_best_tre_25_26.049.pth
# 26 | loss=4.558780
# 26 | tre_before_train=6.479, tre_after_train=4.937, elapsed time: 16.39 sec.
# 26 | tre_before_val=30.364, tre_after_val=26.156, elapsed time: 18.22 sec.
# 27 | loss=4.600717
# 27 | tre_before_train=6.448, tre_after_train=4.951, elapsed time: 15.71 sec.
# 27 | tre_before_val=30.364, tre_after_val=25.948, elapsed time: 17.35 sec.
# 27 | Saving best TRE model: segresnet_kpt_loss_best_tre_27_25.948.pth
# 28 | loss=4.509435
# 28 | tre_before_train=6.479, tre_after_train=4.861, elapsed time: 15.43 sec.
# 28 | tre_before_val=30.364, tre_after_val=25.821, elapsed time: 17.19 sec.
# 28 | Saving best TRE model: segresnet_kpt_loss_best_tre_28_25.821.pth
# 29 | loss=4.369374
# 29 | tre_before_train=6.439, tre_after_train=4.723, elapsed time: 16.37 sec.
# 29 | tre_before_val=30.364, tre_after_val=25.928, elapsed time: 18.05 sec.
# 30 | loss=4.477993
# 30 | tre_before_train=6.491, tre_after_train=4.868, elapsed time: 15.31 sec.
# 30 | tre_before_val=30.364, tre_after_val=26.058, elapsed time: 17.13 sec.
# 31 | loss=4.385302
# 31 | tre_before_train=6.484, tre_after_train=4.752, elapsed time: 14.49 sec.
# 31 | tre_before_val=30.364, tre_after_val=26.072, elapsed time: 16.23 sec.
# 32 | loss=4.200112
# 32 | tre_before_train=6.441, tre_after_train=4.555, elapsed time: 13.22 sec.
# 32 | tre_before_val=30.364, tre_after_val=26.023, elapsed time: 14.80 sec.
# 33 | loss=4.222876
# 33 | tre_before_train=6.432, tre_after_train=4.549, elapsed time: 13.06 sec.
# 33 | tre_before_val=30.364, tre_after_val=26.025, elapsed time: 14.53 sec.
# 34 | loss=4.297594
# 34 | tre_before_train=6.453, tre_after_train=4.645, elapsed time: 13.89 sec.
# 34 | tre_before_val=30.364, tre_after_val=25.882, elapsed time: 15.58 sec.
# 35 | loss=4.159175
# 35 | tre_before_train=6.417, tre_after_train=4.494, elapsed time: 16.05 sec.
# 35 | tre_before_val=30.364, tre_after_val=26.008, elapsed time: 17.73 sec.
# 36 | loss=4.382826
# 36 | tre_before_train=6.538, tre_after_train=4.750, elapsed time: 15.00 sec.
# 36 | tre_before_val=30.364, tre_after_val=26.043, elapsed time: 16.93 sec.
# 37 | loss=4.430556
# 37 | tre_before_train=6.481, tre_after_train=4.799, elapsed time: 14.81 sec.
# 37 | tre_before_val=30.364, tre_after_val=26.166, elapsed time: 16.57 sec.
# 38 | loss=4.381043
# 38 | tre_before_train=6.490, tre_after_train=4.749, elapsed time: 14.20 sec.
# 38 | tre_before_val=30.364, tre_after_val=25.823, elapsed time: 16.02 sec.
# 39 | loss=4.488777
# 39 | tre_before_train=6.527, tre_after_train=4.866, elapsed time: 13.83 sec.
# 39 | tre_before_val=30.364, tre_after_val=25.534, elapsed time: 15.59 sec.
# 39 | Saving best TRE model: segresnet_kpt_loss_best_tre_39_25.534.pth
# 40 | loss=4.348889
# 40 | tre_before_train=6.508, tre_after_train=4.699, elapsed time: 14.01 sec.
# 40 | tre_before_val=30.364, tre_after_val=25.493, elapsed time: 15.78 sec.
# 40 | Saving best TRE model: segresnet_kpt_loss_best_tre_40_25.493.pth
# 41 | loss=4.193292
# 41 | tre_before_train=6.486, tre_after_train=4.542, elapsed time: 13.60 sec.
# 41 | tre_before_val=30.364, tre_after_val=25.569, elapsed time: 15.33 sec.
# 42 | loss=4.032103
# 42 | tre_before_train=6.433, tre_after_train=4.365, elapsed time: 14.04 sec.
# 42 | tre_before_val=30.364, tre_after_val=25.774, elapsed time: 15.62 sec.
# 43 | loss=4.447826
# 43 | tre_before_train=6.535, tre_after_train=4.831, elapsed time: 13.81 sec.
# 43 | tre_before_val=30.364, tre_after_val=25.908, elapsed time: 15.22 sec.
# 44 | loss=4.200431
# 44 | tre_before_train=6.419, tre_after_train=4.510, elapsed time: 13.25 sec.
# 44 | tre_before_val=30.364, tre_after_val=25.821, elapsed time: 14.65 sec.
# 45 | loss=4.190186
# 45 | tre_before_train=6.432, tre_after_train=4.509, elapsed time: 13.19 sec.
# 45 | tre_before_val=30.364, tre_after_val=25.783, elapsed time: 14.55 sec.
# 46 | loss=4.158122
# 46 | tre_before_train=6.494, tre_after_train=4.507, elapsed time: 13.25 sec.
# 46 | tre_before_val=30.364, tre_after_val=25.817, elapsed time: 14.60 sec.
# 47 | loss=4.259864
# 47 | tre_before_train=6.524, tre_after_train=4.606, elapsed time: 13.76 sec.
# 47 | tre_before_val=30.364, tre_after_val=25.820, elapsed time: 15.22 sec.
# 48 | loss=4.446370
# 48 | tre_before_train=6.545, tre_after_train=4.823, elapsed time: 14.01 sec.
# 48 | tre_before_val=30.364, tre_after_val=25.833, elapsed time: 15.53 sec.
# 49 | loss=4.125366
# 49 | tre_before_train=6.456, tre_after_train=4.472, elapsed time: 13.86 sec.
# 49 | tre_before_val=30.364, tre_after_val=25.827, elapsed time: 15.30 sec.
# 50 | loss=4.153737
# 50 | tre_before_train=6.472, tre_after_train=4.483, elapsed time: 14.23 sec.
# 50 | tre_before_val=30.364, tre_after_val=25.825, elapsed time: 15.71 sec.

# %%
# log_val_tre = [x.item() for x in log_val_tre]
fig, axs = plt.subplots(1, 4, figsize=(15, 5))
axs[0].plot(log_train_loss)
axs[0].title.set_text("train_loss")
axs[1].plot(log_val_loss)
axs[1].title.set_text("val_loss")
axs[2].plot(log_train_tre)
axs[2].title.set_text("train_tre")
axs[3].plot(log_val_tre)
axs[3].title.set_text("val_tre")
plt.show()

# %% [markdown]
# Load pretrained model and perform forward pass

# %%
load_pretrained_model_weights = False
if load_pretrained_model_weights:
    dir_load = dir_save  # folder where network weights are stored
    # instantiate warp layer
    warp_layer = Warp()
    # instantiate model
    model = SegResNet(
        spatial_dims=3,
        in_channels=2,
        out_channels=3,
        blocks_down=[1, 2, 2, 4],
        blocks_up=[1, 1, 1],
        init_filters=16,
        dropout_prob=0.2,
    )
    # load model weights
    filename_best_model = glob.glob(os.path.join(dir_load, "segresnet_kpt_loss_best_tre*"))[0]
    model.load_state_dict(torch.load(filename_best_model))
    # to GPU
    model.to(device)

set_determinism(seed=1)
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1, shuffle=True)
check_data = first(check_loader)

# Forward pass
model.eval()
with torch.no_grad():
    ddf_image, ddf_keypoints, pred_image = forward(
            check_data["fixed_image"],
            check_data["moving_image"],
            check_data["fixed_landmarks"],
            model,
            warp_layer,
        )

# %% [markdown]
# Visualization of image pair before and after registration

# %%
def overlay_img(img1, img2, slice_idx, ax, title=None):
    ax.imshow(1 - img1[:, :, slice_idx], cmap="Blues", origin="lower")
    ax.imshow(1 - img2[:, :, slice_idx], cmap="Oranges", origin="lower", alpha=0.5)
    if title is not None:
        ax.set_title(title)  # Use set_title instead of title.set_text

# Image and label visualization
fixed_image = check_data["fixed_image"][0][0].permute(1, 0, 2)
moving_image = check_data["moving_image"][0][0].permute(1, 0, 2)
pred_image = pred_image[0][0].permute(1, 0, 2)

# Pointcloud visualization
fixed_keypoints = check_data["fixed_landmarks"][0]
moving_keypoints = check_data["moving_landmarks"][0]
moved_keypoints = fixed_keypoints + ddf_keypoints[0]

# Plot images and pointclouds
fig, axs = plt.subplots(2, 2, figsize=(10, 12)) 

# Image visualizations
slice_idx = int(target_res[0] * 95.0 / 224) 
overlay_img(fixed_image, moving_image, slice_idx, axs[0, 0], "Before registration")
overlay_img(fixed_image, pred_image, slice_idx, axs[0, 1], "After registration")

# Pointcloud visualizations
ax = fig.add_subplot(2, 2, 3, projection="3d")
ax.scatter(fixed_keypoints[:, 0], fixed_keypoints[:, 1], fixed_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("Before registration")

ax = fig.add_subplot(2, 2, 4, projection="3d")
ax.scatter(moved_keypoints[:, 0], moved_keypoints[:, 1], moved_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("After registration")

# Set axis off for image visualizations
for ax in axs[:, :].flat:
    ax.set_axis_off()

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Computre TRE for the entire model

# %%
# Function to compute predicted TRE for a dataset using the trained model
def compute_tre_for_dataset(model, dataset, warp_layer, vx=None):
    model.eval()
    predicted_tre_list = []
    tre_without_reg = []

    with torch.no_grad():
        for batch_data in dataset:
            fixed_image = batch_data["fixed_image"]
            moving_image = batch_data["moving_image"]
            fixed_keypoints = batch_data["fixed_landmarks"]
            moving_keypoints = batch_data["moving_landmarks"]

            # Forward pass
            ddf_image, ddf_keypoints, pred_image = forward(
                fixed_image, moving_image, fixed_keypoints, model, warp_layer
            )

            # Compute predicted TRE
            noreg_tre = tre(
                fixed_keypoints,
                moving_keypoints,
                vx=vx,
            )
            tre_without_reg.append(noreg_tre)


            predicted_tre = tre(
                fixed_keypoints,
                (fixed_keypoints + ddf_keypoints),
                vx=vx,
            )
            predicted_tre_list.append(predicted_tre)

    return tre_without_reg, predicted_tre_list

# Compute predicted TRE for validation dataset
initial_tre_val, predicted_tre_val = compute_tre_for_dataset(model, val_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_val = pd.DataFrame({
    #"Case": range(1, len(predicted_tre_val) + 1),
    "Case": 4,
    "TRE without registration (Validation)": initial_tre_val,
    "Predicted TRE (Validation)": predicted_tre_val,
})

# Compute predicted TRE for training dataset
initial_tre_train, predicted_tre_train = compute_tre_for_dataset(model, train_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_train = pd.DataFrame({
    "Case": range(1, len(predicted_tre_train) + 1),
    "TRE without registration (Training)": initial_tre_train,
    "Predicted TRE (Training)": predicted_tre_train
})

# Display the combined results
print(df_results_train)
print(df_results_val)
# Out:
#    Case TRE without registration (Training) Predicted TRE (Training)
# 0     1                     tensor(25.0160)       metatensor(7.2533)
# 1     2                     tensor(20.8632)      metatensor(10.2973)
# 2     3                     tensor(12.9761)       metatensor(6.0914)
#    Case TRE without registration (Validation) Predicted TRE (Validation)
# 0     4                       tensor(30.3643)         metatensor(8.4222)

# %%
df_results_train
# Out:
#    Case TRE without registration (Training) Predicted TRE (Training)
# 0     1                     tensor(25.0160)       metatensor(7.2533)
# 1     2                     tensor(20.8632)      metatensor(10.2973)
# 2     3                     tensor(12.9761)       metatensor(6.0914)

# %%
df_results_val
# Out:
#    Case TRE without registration (Validation) Predicted TRE (Validation)
# 0     4                       tensor(30.3643)         metatensor(8.4222)

# %% [markdown]
# #### Training for other models

# %% [markdown]
# VNet

# %%
from monai.networks.nets import VNet

# Model
model = VNet(spatial_dims=3, in_channels=2, out_channels=3, act=('elu', {'inplace': True}), 
             dropout_prob=0.2, dropout_prob_down=0.5, dropout_prob_up=(0.5, 0.5), dropout_dim=3, bias=False)
warp_layer = Warp()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=max_epochs)

# %%
# Tensorboard
if do_save:
    writer = SummaryWriter(log_dir=dir_save)

# Training loop
val_interval = 1
best_eval_tre = float("inf")
log_train_loss = []
log_train_tre = []
log_val_tre = []
log_val_loss = []

pth_best_tre, pth_latest = "", ""

for epoch in range(max_epochs):
    # ==============================================
    # Train
    # ==============================================
    t0_train = time.time()
    model.train()

    epoch_loss, n_steps, tre_before, tre_after = 0, 0, 0, 0
    for batch_data in train_loader:
        # Get data
        fixed_image = batch_data["fixed_image"]
        moving_image = batch_data["moving_image"]
        fixed_keypoints = batch_data["fixed_landmarks"]
        moving_keypoints = batch_data["moving_landmarks"]
        n_steps += 1
        # Forward pass and loss
        optimizer.zero_grad()
        ddf_image, ddf_keypoints, pred_image = forward(
            fixed_image, moving_image, fixed_keypoints, model, warp_layer
        )
        loss = loss_fun(
            fixed_image,
            pred_image,
            fixed_keypoints + ddf_keypoints,
            moving_keypoints,
            ddf_image,
            lam_t,
            lam_m,
            lam_r,
        )
        # Optimise
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        # TRE before (voxel space)
        tre_before += tre(fixed_keypoints, moving_keypoints, vx = vx)
        tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx = vx)

    # Scheduler step
    lr_scheduler.step()
    # Loss
    epoch_loss /= n_steps
    tre_before /= n_steps
    tre_after /= n_steps
    log_train_tre.append(tre_after.item())
    log_train_loss.append(epoch_loss)
    if do_save:
        writer.add_scalar("train_loss", epoch_loss, epoch)
    print(f"{epoch + 1} | loss={epoch_loss:.6f}")

    # Mean TRE
    tre_before /= n_steps
    tre_after /= n_steps
    print(
            f"{epoch + 1} | tre_before_train={tre_before:.3f}, tre_after_train={tre_after:.3f}, elapsed time: {time.time()-t0_train:.2f} sec."
    )

    # ==============================================
    # Eval
    # ==============================================
    if (epoch + 1) % val_interval == 0:
        t0_eval = time.time()
        model.eval()

        val_epoch_loss , n_steps, tre_before, tre_after = 0, 0, 0, 0
        with torch.no_grad():
            for batch_data in val_loader:
                # Get data
                fixed_image = batch_data["fixed_image"]
                moving_image = batch_data["moving_image"]
                fixed_keypoints = batch_data["fixed_landmarks"]
                moving_keypoints = batch_data["moving_landmarks"]
                n_steps += 1

                # Infer
                ddf_image, ddf_keypoints, pred_image = forward(
                    fixed_image, moving_image, fixed_keypoints, model, warp_layer
                )

                # Loss for validation
                val_loss = loss_fun(
                    fixed_image,
                    pred_image,
                    fixed_keypoints + ddf_keypoints,
                    moving_keypoints,
                    ddf_image,
                    lam_t,
                    lam_m,
                    lam_r,
                )
                val_epoch_loss += val_loss.item()

                # TRE

                tre_before += tre(fixed_keypoints , moving_keypoints, vx=vx)
                tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx=vx)

        # Mean TRE
        tre_before /= n_steps
        tre_after /= n_steps
        val_epoch_loss /= n_steps
        log_val_loss.append(val_epoch_loss)
        log_val_tre.append(tre_after.item())
        if do_save:
            writer.add_scalar("val_tre", tre_after, epoch)
       

        print(
            f"{epoch + 1} | tre_before_val={tre_before:.3f}, tre_after_val={tre_after:.3f}, elapsed time: {time.time() - t0_train:.2f} sec."
            )


        if tre_after < best_eval_tre:
            best_eval_tre = tre_after
            if do_save:
                # Save best model based on TRE
                if pth_best_tre != "":
                    os.remove(os.path.join(dir_save, pth_best_tre))
                pth_best_tre = f"VNet_kpt_loss_best_tre_{epoch + 1}_{best_eval_tre:.3f}.pth"
                torch.save(model.state_dict(), os.path.join(dir_save, pth_best_tre))
                print(f"{epoch + 1} | Saving best TRE model: {pth_best_tre}")

        if do_save:
            # Save latest model
            if pth_latest != "":
                os.remove(os.path.join(dir_save, pth_latest))
            pth_latest = "VNet_kpt_loss_latest.pth"
            torch.save(model.state_dict(), os.path.join(dir_save, pth_latest))
# Out:
# 1 | loss=6.548649
# 1 | tre_before_train=6.437, tre_after_train=6.814, elapsed time: 31.10 sec.
# 1 | tre_before_val=30.364, tre_after_val=30.025, elapsed time: 34.52 sec.
# 1 | Saving best TRE model: VNet_kpt_loss_best_tre_1_30.025.pth
# 2 | loss=6.135309
# 2 | tre_before_train=6.431, tre_after_train=6.437, elapsed time: 35.25 sec.
# 2 | tre_before_val=30.364, tre_after_val=29.759, elapsed time: 39.99 sec.
# 2 | Saving best TRE model: VNet_kpt_loss_best_tre_2_29.759.pth
# 3 | loss=5.960022
# 3 | tre_before_train=6.402, tre_after_train=6.244, elapsed time: 35.74 sec.
# 3 | tre_before_val=30.364, tre_after_val=29.435, elapsed time: 39.77 sec.
# 3 | Saving best TRE model: VNet_kpt_loss_best_tre_3_29.435.pth
# 4 | loss=5.986105
# 4 | tre_before_train=6.468, tre_after_train=6.295, elapsed time: 37.21 sec.
# 4 | tre_before_val=30.364, tre_after_val=29.321, elapsed time: 41.20 sec.
# 4 | Saving best TRE model: VNet_kpt_loss_best_tre_4_29.321.pth
# 5 | loss=5.931060
# 5 | tre_before_train=6.482, tre_after_train=6.249, elapsed time: 35.21 sec.
# 5 | tre_before_val=30.364, tre_after_val=29.247, elapsed time: 39.23 sec.
# 5 | Saving best TRE model: VNet_kpt_loss_best_tre_5_29.247.pth
# 6 | loss=5.959620
# 6 | tre_before_train=6.465, tre_after_train=6.314, elapsed time: 37.05 sec.
# 6 | tre_before_val=30.364, tre_after_val=29.192, elapsed time: 41.53 sec.
# 6 | Saving best TRE model: VNet_kpt_loss_best_tre_6_29.192.pth
# 7 | loss=5.883905
# 7 | tre_before_train=6.453, tre_after_train=6.174, elapsed time: 36.04 sec.
# 7 | tre_before_val=30.364, tre_after_val=29.216, elapsed time: 40.07 sec.
# 8 | loss=5.968847
# 8 | tre_before_train=6.494, tre_after_train=6.282, elapsed time: 37.55 sec.
# 8 | tre_before_val=30.364, tre_after_val=29.200, elapsed time: 41.87 sec.
# 9 | loss=5.890498
# 9 | tre_before_train=6.507, tre_after_train=6.221, elapsed time: 36.77 sec.
# 9 | tre_before_val=30.364, tre_after_val=29.189, elapsed time: 40.86 sec.
# 9 | Saving best TRE model: VNet_kpt_loss_best_tre_9_29.189.pth
# 10 | loss=5.806600
# 10 | tre_before_train=6.639, tre_after_train=6.147, elapsed time: 38.20 sec.
# 10 | tre_before_val=30.364, tre_after_val=29.200, elapsed time: 42.42 sec.
# 11 | loss=5.842566
# 11 | tre_before_train=6.722, tre_after_train=6.202, elapsed time: 38.91 sec.
# 11 | tre_before_val=30.364, tre_after_val=29.160, elapsed time: 43.28 sec.
# 11 | Saving best TRE model: VNet_kpt_loss_best_tre_11_29.160.pth
# 12 | loss=5.919684
# 12 | tre_before_train=6.434, tre_after_train=6.225, elapsed time: 39.84 sec.
# 12 | tre_before_val=30.364, tre_after_val=29.163, elapsed time: 44.34 sec.
# 13 | loss=5.900727
# 13 | tre_before_train=6.436, tre_after_train=6.200, elapsed time: 40.59 sec.
# 13 | tre_before_val=30.364, tre_after_val=29.135, elapsed time: 45.65 sec.
# 13 | Saving best TRE model: VNet_kpt_loss_best_tre_13_29.135.pth
# 14 | loss=5.795587
# 14 | tre_before_train=6.454, tre_after_train=6.083, elapsed time: 40.17 sec.
# 14 | tre_before_val=30.364, tre_after_val=29.093, elapsed time: 44.78 sec.
# 14 | Saving best TRE model: VNet_kpt_loss_best_tre_14_29.093.pth
# 15 | loss=5.930156
# 15 | tre_before_train=6.463, tre_after_train=6.226, elapsed time: 38.86 sec.
# 15 | tre_before_val=30.364, tre_after_val=29.092, elapsed time: 43.19 sec.
# 15 | Saving best TRE model: VNet_kpt_loss_best_tre_15_29.092.pth
# 16 | loss=5.865240
# 16 | tre_before_train=6.471, tre_after_train=6.178, elapsed time: 39.98 sec.
# 16 | tre_before_val=30.364, tre_after_val=29.122, elapsed time: 44.39 sec.
# 17 | loss=5.913251
# 17 | tre_before_train=6.470, tre_after_train=6.224, elapsed time: 39.61 sec.
# 17 | tre_before_val=30.364, tre_after_val=29.132, elapsed time: 43.83 sec.
# 18 | loss=5.947122
# 18 | tre_before_train=6.578, tre_after_train=6.300, elapsed time: 39.06 sec.
# 18 | tre_before_val=30.364, tre_after_val=29.105, elapsed time: 45.48 sec.
# 19 | loss=5.845230
# 19 | tre_before_train=6.570, tre_after_train=6.197, elapsed time: 40.19 sec.
# 19 | tre_before_val=30.364, tre_after_val=29.042, elapsed time: 45.06 sec.
# 19 | Saving best TRE model: VNet_kpt_loss_best_tre_19_29.042.pth
# 20 | loss=5.724258
# 20 | tre_before_train=6.558, tre_after_train=6.037, elapsed time: 38.96 sec.
# 20 | tre_before_val=30.364, tre_after_val=29.051, elapsed time: 43.37 sec.
# 21 | loss=5.756014
# 21 | tre_before_train=6.441, tre_after_train=6.062, elapsed time: 39.46 sec.
# 21 | tre_before_val=30.364, tre_after_val=29.067, elapsed time: 43.82 sec.
# 22 | loss=5.965582
# 22 | tre_before_train=6.521, tre_after_train=6.311, elapsed time: 38.64 sec.
# 22 | tre_before_val=30.364, tre_after_val=28.975, elapsed time: 43.05 sec.
# 22 | Saving best TRE model: VNet_kpt_loss_best_tre_22_28.975.pth
# 23 | loss=5.818418
# 23 | tre_before_train=6.467, tre_after_train=6.139, elapsed time: 37.36 sec.
# 23 | tre_before_val=30.364, tre_after_val=28.922, elapsed time: 41.46 sec.
# 23 | Saving best TRE model: VNet_kpt_loss_best_tre_23_28.922.pth
# 24 | loss=5.902941
# 24 | tre_before_train=6.494, tre_after_train=6.237, elapsed time: 36.65 sec.
# 24 | tre_before_val=30.364, tre_after_val=28.900, elapsed time: 41.41 sec.
# 24 | Saving best TRE model: VNet_kpt_loss_best_tre_24_28.900.pth
# 25 | loss=5.892555
# 25 | tre_before_train=6.509, tre_after_train=6.237, elapsed time: 39.59 sec.
# 25 | tre_before_val=30.364, tre_after_val=28.852, elapsed time: 44.10 sec.
# 25 | Saving best TRE model: VNet_kpt_loss_best_tre_25_28.852.pth
# 26 | loss=5.802387
# 26 | tre_before_train=6.519, tre_after_train=6.130, elapsed time: 40.48 sec.
# 26 | tre_before_val=30.364, tre_after_val=28.826, elapsed time: 44.89 sec.
# 26 | Saving best TRE model: VNet_kpt_loss_best_tre_26_28.826.pth
# 27 | loss=5.693408
# 27 | tre_before_train=6.513, tre_after_train=5.987, elapsed time: 39.06 sec.
# 27 | tre_before_val=30.364, tre_after_val=28.955, elapsed time: 43.31 sec.
# 28 | loss=5.767789
# 28 | tre_before_train=6.460, tre_after_train=6.063, elapsed time: 38.78 sec.
# 28 | tre_before_val=30.364, tre_after_val=29.012, elapsed time: 43.95 sec.
# 29 | loss=5.761359
# 29 | tre_before_train=6.465, tre_after_train=6.077, elapsed time: 39.28 sec.
# 29 | tre_before_val=30.364, tre_after_val=28.931, elapsed time: 43.86 sec.
# 30 | loss=5.814207
# 30 | tre_before_train=6.496, tre_after_train=6.153, elapsed time: 38.81 sec.
# 30 | tre_before_val=30.364, tre_after_val=28.850, elapsed time: 43.11 sec.
# 31 | loss=5.857709
# 31 | tre_before_train=6.485, tre_after_train=6.156, elapsed time: 38.95 sec.
# 31 | tre_before_val=30.364, tre_after_val=28.779, elapsed time: 43.15 sec.
# 31 | Saving best TRE model: VNet_kpt_loss_best_tre_31_28.779.pth
# 32 | loss=5.872624
# 32 | tre_before_train=6.498, tre_after_train=6.199, elapsed time: 38.42 sec.
# 32 | tre_before_val=30.364, tre_after_val=28.746, elapsed time: 43.05 sec.
# 32 | Saving best TRE model: VNet_kpt_loss_best_tre_32_28.746.pth
# 33 | loss=5.731848
# 33 | tre_before_train=6.444, tre_after_train=6.013, elapsed time: 39.12 sec.
# 33 | tre_before_val=30.364, tre_after_val=28.747, elapsed time: 43.62 sec.
# 34 | loss=5.847964
# 34 | tre_before_train=6.478, tre_after_train=6.165, elapsed time: 40.35 sec.
# 34 | tre_before_val=30.364, tre_after_val=28.763, elapsed time: 44.85 sec.
# 35 | loss=5.788960
# 35 | tre_before_train=6.460, tre_after_train=6.086, elapsed time: 38.94 sec.
# 35 | tre_before_val=30.364, tre_after_val=28.786, elapsed time: 43.27 sec.
# 36 | loss=5.837594
# 36 | tre_before_train=6.403, tre_after_train=6.116, elapsed time: 38.16 sec.
# 36 | tre_before_val=30.364, tre_after_val=28.792, elapsed time: 42.86 sec.
# 37 | loss=5.844918
# 37 | tre_before_train=6.455, tre_after_train=6.164, elapsed time: 38.45 sec.
# 37 | tre_before_val=30.364, tre_after_val=28.769, elapsed time: 42.86 sec.
# 38 | loss=5.789002
# 38 | tre_before_train=6.482, tre_after_train=6.100, elapsed time: 40.09 sec.
# 38 | tre_before_val=30.364, tre_after_val=28.748, elapsed time: 44.65 sec.
# 39 | loss=5.763295
# 39 | tre_before_train=6.449, tre_after_train=6.054, elapsed time: 38.96 sec.
# 39 | tre_before_val=30.364, tre_after_val=28.722, elapsed time: 43.15 sec.
# 39 | Saving best TRE model: VNet_kpt_loss_best_tre_39_28.722.pth
# 40 | loss=5.726465
# 40 | tre_before_train=6.508, tre_after_train=6.023, elapsed time: 35.47 sec.
# 40 | tre_before_val=30.364, tre_after_val=28.682, elapsed time: 39.65 sec.
# 40 | Saving best TRE model: VNet_kpt_loss_best_tre_40_28.682.pth
# 41 | loss=5.824754
# 41 | tre_before_train=6.492, tre_after_train=6.132, elapsed time: 37.68 sec.
# 41 | tre_before_val=30.364, tre_after_val=28.660, elapsed time: 42.29 sec.
# 41 | Saving best TRE model: VNet_kpt_loss_best_tre_41_28.660.pth
# 42 | loss=5.794764
# 42 | tre_before_train=6.410, tre_after_train=6.095, elapsed time: 38.66 sec.
# 42 | tre_before_val=30.364, tre_after_val=28.647, elapsed time: 43.06 sec.
# 42 | Saving best TRE model: VNet_kpt_loss_best_tre_42_28.647.pth
# 43 | loss=5.749929
# 43 | tre_before_train=6.506, tre_after_train=6.060, elapsed time: 39.48 sec.
# 43 | tre_before_val=30.364, tre_after_val=28.657, elapsed time: 43.90 sec.
# 44 | loss=5.800215
# 44 | tre_before_train=6.510, tre_after_train=6.111, elapsed time: 40.46 sec.
# 44 | tre_before_val=30.364, tre_after_val=28.677, elapsed time: 45.43 sec.
# 45 | loss=5.823165
# 45 | tre_before_train=6.495, tre_after_train=6.132, elapsed time: 39.90 sec.
# 45 | tre_before_val=30.364, tre_after_val=28.688, elapsed time: 44.17 sec.
# 46 | loss=5.780604
# 46 | tre_before_train=6.448, tre_after_train=6.075, elapsed time: 37.51 sec.
# 46 | tre_before_val=30.364, tre_after_val=28.695, elapsed time: 41.79 sec.
# 47 | loss=5.823927
# 47 | tre_before_train=6.445, tre_after_train=6.149, elapsed time: 37.56 sec.
# 47 | tre_before_val=30.364, tre_after_val=28.683, elapsed time: 41.87 sec.
# 48 | loss=5.822496
# 48 | tre_before_train=6.434, tre_after_train=6.124, elapsed time: 38.73 sec.
# 48 | tre_before_val=30.364, tre_after_val=28.678, elapsed time: 43.08 sec.
# 49 | loss=5.886115
# 49 | tre_before_train=6.502, tre_after_train=6.167, elapsed time: 39.79 sec.
# 49 | tre_before_val=30.364, tre_after_val=28.683, elapsed time: 44.54 sec.
# 50 | loss=5.763244
# 50 | tre_before_train=6.426, tre_after_train=6.024, elapsed time: 40.03 sec.
# 50 | tre_before_val=30.364, tre_after_val=28.693, elapsed time: 44.81 sec.

# %%
# log_val_tre = [x.item() for x in log_val_tre]
fig, axs = plt.subplots(1, 4, figsize=(15, 5))
axs[0].plot(log_train_loss)
axs[0].title.set_text("VNet train_loss")
axs[1].plot(log_val_loss)
axs[1].title.set_text("VNet val_loss")
axs[2].plot(log_train_tre)
axs[2].title.set_text("VNet train_tre")
axs[3].plot(log_val_tre)
axs[3].title.set_text("VNet val_tre")
plt.show()

# %%
load_pretrained_model_weights = False
if load_pretrained_model_weights:
    dir_load = dir_save  # folder where network weights are stored
    # instantiate warp layer
    warp_layer = Warp()
    # instantiate model
    model = VNet(spatial_dims=3, in_channels=2, out_channels=3, act=('elu', {'inplace': True}), 
             dropout_prob=0.2, dropout_prob_down=0.5, dropout_prob_up=(0.5, 0.5), dropout_dim=3, bias=False)
    # load model weights
    filename_best_model = glob.glob(os.path.join(dir_load, "VNet_kpt_loss_best_tre*"))[0]
    model.load_state_dict(torch.load(filename_best_model))
    # to GPU
    model.to(device)

set_determinism(seed=1)
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1, shuffle=True)
check_data = first(check_loader)

# Forward pass
model.eval()
with torch.no_grad():
    ddf_image, ddf_keypoints, pred_image = forward(
            check_data["fixed_image"],
            check_data["moving_image"],
            check_data["fixed_landmarks"],
            model,
            warp_layer,
        )
        
        
def overlay_img(img1, img2, slice_idx, ax, title=None):
    ax.imshow(1 - img1[:, :, slice_idx], cmap="Blues", origin="lower")
    ax.imshow(1 - img2[:, :, slice_idx], cmap="Oranges", origin="lower", alpha=0.5)
    if title is not None:
        ax.set_title(title)  # Use set_title instead of title.set_text

# Image and label visualization
fixed_image = check_data["fixed_image"][0][0].permute(1, 0, 2)
moving_image = check_data["moving_image"][0][0].permute(1, 0, 2)
pred_image = pred_image[0][0].permute(1, 0, 2)

# Pointcloud visualization
fixed_keypoints = check_data["fixed_landmarks"][0]
moving_keypoints = check_data["moving_landmarks"][0]
moved_keypoints = fixed_keypoints + ddf_keypoints[0]

# Plot images and pointclouds
fig, axs = plt.subplots(2, 2, figsize=(10, 12)) 

# Image visualizations
slice_idx = int(target_res[0] * 95.0 / 224) 
overlay_img(fixed_image, moving_image, slice_idx, axs[0, 0], "Before registration")
overlay_img(fixed_image, pred_image, slice_idx, axs[0, 1], "After registration using VNet")

# Pointcloud visualizations
ax = fig.add_subplot(2, 2, 3, projection="3d")
ax.scatter(fixed_keypoints[:, 0], fixed_keypoints[:, 1], fixed_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("Before registration")

ax = fig.add_subplot(2, 2, 4, projection="3d")
ax.scatter(moved_keypoints[:, 0], moved_keypoints[:, 1], moved_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("After registration using VNet")

# Set axis off for image visualizations
for ax in axs[:, :].flat:
    ax.set_axis_off()

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Compute predicted TRE for validation dataset
_, predicted_tre_val = compute_tre_for_dataset(model, val_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_val = pd.DataFrame({
    #"Case": range(1, len(predicted_tre_val) + 1),
    "Case": 4,
    "VNet Predicted TRE (Validation)": predicted_tre_val,
})

# Compute predicted TRE for training dataset
_, predicted_tre_train = compute_tre_for_dataset(model, train_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_train = pd.DataFrame({
    "Case": range(1, len(predicted_tre_train) + 1),
    "VNet Predicted TRE (Training)": predicted_tre_train
})

# Display the combined results
print(df_results_train)
print(df_results_val)
# Out:
#    Case VNet Predicted TRE (Training)
# 0     1            metatensor(3.3773)
# 1     2            metatensor(3.2669)
# 2     3            metatensor(4.0019)
#    Case VNet Predicted TRE (Validation)
# 0     4              metatensor(4.1112)

# %% [markdown]
# Autoencoder

# %%
from monai.networks.nets import AutoEncoder

# Model
model = AutoEncoder(spatial_dims = 3, in_channels = 2, out_channels = 3,  channels=(2, 4, 8), strides=(2, 2, 2), 
                    kernel_size=3, up_kernel_size=3, num_res_units=0, inter_channels=None, 
                    inter_dilations=None, num_inter_units=2, act='PRELU', norm='INSTANCE', dropout=None, bias=True, padding=None)
warp_layer = Warp()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=max_epochs)

# %%
# Tensorboard
if do_save:
    writer = SummaryWriter(log_dir=dir_save)

# Training loop
val_interval = 1
best_eval_tre = float("inf")
log_train_loss = []
log_train_tre = []
log_val_tre = []
log_val_loss = []

pth_best_tre, pth_latest = "", ""

for epoch in range(max_epochs):
    # ==============================================
    # Train
    # ==============================================
    t0_train = time.time()
    model.train()

    epoch_loss, n_steps, tre_before, tre_after = 0, 0, 0, 0
    for batch_data in train_loader:
        # Get data
        fixed_image = batch_data["fixed_image"]
        moving_image = batch_data["moving_image"]
        fixed_keypoints = batch_data["fixed_landmarks"]
        moving_keypoints = batch_data["moving_landmarks"]
        n_steps += 1
        # Forward pass and loss
        optimizer.zero_grad()
        ddf_image, ddf_keypoints, pred_image = forward(
            fixed_image, moving_image, fixed_keypoints, model, warp_layer
        )
        loss = loss_fun(
            fixed_image,
            pred_image,
            fixed_keypoints + ddf_keypoints,
            moving_keypoints,
            ddf_image,
            lam_t,
            lam_m,
            lam_r,
        )
        # Optimise
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        # TRE before (voxel space)
        tre_before += tre(fixed_keypoints, moving_keypoints, vx = vx)
        tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx = vx)

    # Scheduler step
    lr_scheduler.step()
    # Loss
    epoch_loss /= n_steps
    tre_before /= n_steps
    tre_after /= n_steps
    log_train_tre.append(tre_after.item())
    log_train_loss.append(epoch_loss)
    if do_save:
        writer.add_scalar("train_loss", epoch_loss, epoch)
    print(f"{epoch + 1} | loss={epoch_loss:.6f}")

    # Mean TRE
    tre_before /= n_steps
    tre_after /= n_steps
    print(
            f"{epoch + 1} | tre_before_train={tre_before:.3f}, tre_after_train={tre_after:.3f}, elapsed time: {time.time()-t0_train:.2f} sec."
    )

    # ==============================================
    # Eval
    # ==============================================
    if (epoch + 1) % val_interval == 0:
        t0_eval = time.time()
        model.eval()

        val_epoch_loss , n_steps, tre_before, tre_after = 0, 0, 0, 0
        with torch.no_grad():
            for batch_data in val_loader:
                # Get data
                fixed_image = batch_data["fixed_image"]
                moving_image = batch_data["moving_image"]
                fixed_keypoints = batch_data["fixed_landmarks"]
                moving_keypoints = batch_data["moving_landmarks"]
                n_steps += 1

                # Infer
                ddf_image, ddf_keypoints, pred_image = forward(
                    fixed_image, moving_image, fixed_keypoints, model, warp_layer
                )

                # Loss for validation
                val_loss = loss_fun(
                    fixed_image,
                    pred_image,
                    fixed_keypoints + ddf_keypoints,
                    moving_keypoints,
                    ddf_image,
                    lam_t,
                    lam_m,
                    lam_r,
                )
                val_epoch_loss += val_loss.item()

                # TRE

                tre_before += tre(fixed_keypoints , moving_keypoints, vx=vx)
                tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx=vx)

        # Mean TRE
        tre_before /= n_steps
        tre_after /= n_steps
        val_epoch_loss /= n_steps
        log_val_loss.append(val_epoch_loss)
        log_val_tre.append(tre_after.item())
        if do_save:
            writer.add_scalar("val_tre", tre_after, epoch)
       

        print(
            f"{epoch + 1} | tre_before_val={tre_before:.3f}, tre_after_val={tre_after:.3f}, elapsed time: {time.time() - t0_train:.2f} sec."
            )


        if tre_after < best_eval_tre:
            best_eval_tre = tre_after
            if do_save:
                # Save best model based on TRE
                if pth_best_tre != "":
                    os.remove(os.path.join(dir_save, pth_best_tre))
                pth_best_tre = f"Autoencoder_kpt_loss_best_tre_{epoch + 1}_{best_eval_tre:.3f}.pth"
                torch.save(model.state_dict(), os.path.join(dir_save, pth_best_tre))
                print(f"{epoch + 1} | Saving best TRE model: {pth_best_tre}")

        if do_save:
            # Save latest model
            if pth_latest != "":
                os.remove(os.path.join(dir_save, pth_latest))
            pth_latest = "Autoencoder_kpt_loss_latest.pth"
            torch.save(model.state_dict(), os.path.join(dir_save, pth_latest))
# Out:
# 1 | loss=6.030278
# 1 | tre_before_train=6.413, tre_after_train=6.341, elapsed time: 0.95 sec.
# 1 | tre_before_val=30.364, tre_after_val=30.315, elapsed time: 1.22 sec.
# 1 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_1_30.315.pth
# 2 | loss=6.100541
# 2 | tre_before_train=6.512, tre_after_train=6.459, elapsed time: 1.01 sec.
# 2 | tre_before_val=30.364, tre_after_val=30.313, elapsed time: 1.14 sec.
# 2 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_2_30.313.pth
# 3 | loss=6.063825
# 3 | tre_before_train=6.479, tre_after_train=6.414, elapsed time: 0.96 sec.
# 3 | tre_before_val=30.364, tre_after_val=30.311, elapsed time: 1.09 sec.
# 3 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_3_30.311.pth
# 4 | loss=6.063401
# 4 | tre_before_train=6.454, tre_after_train=6.393, elapsed time: 0.92 sec.
# 4 | tre_before_val=30.364, tre_after_val=30.310, elapsed time: 1.04 sec.
# 4 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_4_30.310.pth
# 5 | loss=6.161222
# 5 | tre_before_train=6.589, tre_after_train=6.534, elapsed time: 1.05 sec.
# 5 | tre_before_val=30.364, tre_after_val=30.308, elapsed time: 1.17 sec.
# 5 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_5_30.308.pth
# 6 | loss=6.061680
# 6 | tre_before_train=6.468, tre_after_train=6.411, elapsed time: 0.76 sec.
# 6 | tre_before_val=30.364, tre_after_val=30.307, elapsed time: 0.87 sec.
# 6 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_6_30.307.pth
# 7 | loss=6.142077
# 7 | tre_before_train=6.583, tre_after_train=6.520, elapsed time: 0.89 sec.
# 7 | tre_before_val=30.364, tre_after_val=30.305, elapsed time: 1.02 sec.
# 7 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_7_30.305.pth
# 8 | loss=6.122524
# 8 | tre_before_train=6.541, tre_after_train=6.476, elapsed time: 0.89 sec.
# 8 | tre_before_val=30.364, tre_after_val=30.303, elapsed time: 1.01 sec.
# 8 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_8_30.303.pth
# 9 | loss=6.031332
# 9 | tre_before_train=6.427, tre_after_train=6.365, elapsed time: 0.78 sec.
# 9 | tre_before_val=30.364, tre_after_val=30.301, elapsed time: 0.90 sec.
# 9 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_9_30.301.pth
# 10 | loss=6.049796
# 10 | tre_before_train=6.449, tre_after_train=6.381, elapsed time: 0.76 sec.
# 10 | tre_before_val=30.364, tre_after_val=30.300, elapsed time: 0.87 sec.
# 10 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_10_30.300.pth
# 11 | loss=6.044964
# 11 | tre_before_train=6.430, tre_after_train=6.358, elapsed time: 0.87 sec.
# 11 | tre_before_val=30.364, tre_after_val=30.298, elapsed time: 0.97 sec.
# 11 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_11_30.298.pth
# 12 | loss=6.044198
# 12 | tre_before_train=6.431, tre_after_train=6.356, elapsed time: 0.89 sec.
# 12 | tre_before_val=30.364, tre_after_val=30.296, elapsed time: 0.99 sec.
# 12 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_12_30.296.pth
# 13 | loss=6.054075
# 13 | tre_before_train=6.470, tre_after_train=6.399, elapsed time: 0.79 sec.
# 13 | tre_before_val=30.364, tre_after_val=30.295, elapsed time: 0.90 sec.
# 13 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_13_30.295.pth
# 14 | loss=6.132318
# 14 | tre_before_train=6.590, tre_after_train=6.537, elapsed time: 0.86 sec.
# 14 | tre_before_val=30.364, tre_after_val=30.293, elapsed time: 0.98 sec.
# 14 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_14_30.293.pth
# 15 | loss=6.088492
# 15 | tre_before_train=6.507, tre_after_train=6.433, elapsed time: 0.77 sec.
# 15 | tre_before_val=30.364, tre_after_val=30.292, elapsed time: 0.88 sec.
# 15 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_15_30.292.pth
# 16 | loss=6.067077
# 16 | tre_before_train=6.476, tre_after_train=6.402, elapsed time: 0.78 sec.
# 16 | tre_before_val=30.364, tre_after_val=30.290, elapsed time: 0.90 sec.
# 16 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_16_30.290.pth
# 17 | loss=6.063492
# 17 | tre_before_train=6.504, tre_after_train=6.441, elapsed time: 0.91 sec.
# 17 | tre_before_val=30.364, tre_after_val=30.289, elapsed time: 1.02 sec.
# 17 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_17_30.289.pth
# 18 | loss=6.051548
# 18 | tre_before_train=6.454, tre_after_train=6.388, elapsed time: 1.03 sec.
# 18 | tre_before_val=30.364, tre_after_val=30.287, elapsed time: 1.15 sec.
# 18 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_18_30.287.pth
# 19 | loss=6.059606
# 19 | tre_before_train=6.484, tre_after_train=6.421, elapsed time: 0.95 sec.
# 19 | tre_before_val=30.364, tre_after_val=30.286, elapsed time: 1.07 sec.
# 19 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_19_30.286.pth
# 20 | loss=6.116976
# 20 | tre_before_train=6.500, tre_after_train=6.429, elapsed time: 0.92 sec.
# 20 | tre_before_val=30.364, tre_after_val=30.285, elapsed time: 1.03 sec.
# 20 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_20_30.285.pth
# 21 | loss=6.081401
# 21 | tre_before_train=6.494, tre_after_train=6.414, elapsed time: 1.03 sec.
# 21 | tre_before_val=30.364, tre_after_val=30.284, elapsed time: 1.14 sec.
# 21 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_21_30.284.pth
# 22 | loss=6.028116
# 22 | tre_before_train=6.441, tre_after_train=6.369, elapsed time: 0.98 sec.
# 22 | tre_before_val=30.364, tre_after_val=30.283, elapsed time: 1.10 sec.
# 22 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_22_30.283.pth
# 23 | loss=6.044781
# 23 | tre_before_train=6.446, tre_after_train=6.361, elapsed time: 1.01 sec.
# 23 | tre_before_val=30.364, tre_after_val=30.282, elapsed time: 1.13 sec.
# 23 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_23_30.282.pth
# 24 | loss=6.144590
# 24 | tre_before_train=6.573, tre_after_train=6.510, elapsed time: 0.98 sec.
# 24 | tre_before_val=30.364, tre_after_val=30.281, elapsed time: 1.09 sec.
# 24 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_24_30.281.pth
# 25 | loss=6.047866
# 25 | tre_before_train=6.485, tre_after_train=6.408, elapsed time: 1.04 sec.
# 25 | tre_before_val=30.364, tre_after_val=30.280, elapsed time: 1.15 sec.
# 25 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_25_30.280.pth
# 26 | loss=6.065284
# 26 | tre_before_train=6.484, tre_after_train=6.409, elapsed time: 0.94 sec.
# 26 | tre_before_val=30.364, tre_after_val=30.279, elapsed time: 1.06 sec.
# 26 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_26_30.279.pth
# 27 | loss=6.059047
# 27 | tre_before_train=6.481, tre_after_train=6.401, elapsed time: 0.96 sec.
# 27 | tre_before_val=30.364, tre_after_val=30.278, elapsed time: 1.07 sec.
# 27 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_27_30.278.pth
# 28 | loss=6.050380
# 28 | tre_before_train=6.463, tre_after_train=6.386, elapsed time: 0.79 sec.
# 28 | tre_before_val=30.364, tre_after_val=30.277, elapsed time: 0.90 sec.
# 28 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_28_30.277.pth
# 29 | loss=6.136069
# 29 | tre_before_train=6.576, tre_after_train=6.516, elapsed time: 0.90 sec.
# 29 | tre_before_val=30.364, tre_after_val=30.276, elapsed time: 1.02 sec.
# 29 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_29_30.276.pth
# 30 | loss=6.081547
# 30 | tre_before_train=6.517, tre_after_train=6.436, elapsed time: 0.94 sec.
# 30 | tre_before_val=30.364, tre_after_val=30.275, elapsed time: 1.04 sec.
# 30 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_30_30.275.pth
# 31 | loss=6.064816
# 31 | tre_before_train=6.506, tre_after_train=6.430, elapsed time: 1.01 sec.
# 31 | tre_before_val=30.364, tre_after_val=30.275, elapsed time: 1.12 sec.
# 31 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_31_30.275.pth
# 32 | loss=6.077546
# 32 | tre_before_train=6.505, tre_after_train=6.428, elapsed time: 1.00 sec.
# 32 | tre_before_val=30.364, tre_after_val=30.274, elapsed time: 1.12 sec.
# 32 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_32_30.274.pth
# 33 | loss=6.023104
# 33 | tre_before_train=6.439, tre_after_train=6.360, elapsed time: 0.98 sec.
# 33 | tre_before_val=30.364, tre_after_val=30.273, elapsed time: 1.13 sec.
# 33 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_33_30.273.pth
# 34 | loss=6.070145
# 34 | tre_before_train=6.493, tre_after_train=6.418, elapsed time: 1.03 sec.
# 34 | tre_before_val=30.364, tre_after_val=30.273, elapsed time: 1.18 sec.
# 34 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_34_30.273.pth
# 35 | loss=6.123201
# 35 | tre_before_train=6.561, tre_after_train=6.501, elapsed time: 1.06 sec.
# 35 | tre_before_val=30.364, tre_after_val=30.273, elapsed time: 1.25 sec.
# 35 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_35_30.273.pth
# 36 | loss=6.054756
# 36 | tre_before_train=6.459, tre_after_train=6.368, elapsed time: 1.01 sec.
# 36 | tre_before_val=30.364, tre_after_val=30.272, elapsed time: 1.13 sec.
# 36 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_36_30.272.pth
# 37 | loss=6.121430
# 37 | tre_before_train=6.560, tre_after_train=6.490, elapsed time: 1.01 sec.
# 37 | tre_before_val=30.364, tre_after_val=30.272, elapsed time: 1.13 sec.
# 37 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_37_30.272.pth
# 38 | loss=6.009104
# 38 | tre_before_train=6.417, tre_after_train=6.337, elapsed time: 0.90 sec.
# 38 | tre_before_val=30.364, tre_after_val=30.272, elapsed time: 1.02 sec.
# 38 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_38_30.272.pth
# 39 | loss=6.076273
# 39 | tre_before_train=6.489, tre_after_train=6.406, elapsed time: 1.03 sec.
# 39 | tre_before_val=30.364, tre_after_val=30.271, elapsed time: 1.17 sec.
# 39 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_39_30.271.pth
# 40 | loss=6.076412
# 40 | tre_before_train=6.537, tre_after_train=6.478, elapsed time: 1.44 sec.
# 40 | tre_before_val=30.364, tre_after_val=30.271, elapsed time: 1.60 sec.
# 40 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_40_30.271.pth
# 41 | loss=6.082812
# 41 | tre_before_train=6.514, tre_after_train=6.437, elapsed time: 1.00 sec.
# 41 | tre_before_val=30.364, tre_after_val=30.271, elapsed time: 1.19 sec.
# 41 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_41_30.271.pth
# 42 | loss=6.034814
# 42 | tre_before_train=6.464, tre_after_train=6.389, elapsed time: 1.03 sec.
# 42 | tre_before_val=30.364, tre_after_val=30.271, elapsed time: 1.16 sec.
# 42 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_42_30.271.pth
# 43 | loss=6.046080
# 43 | tre_before_train=6.473, tre_after_train=6.406, elapsed time: 1.17 sec.
# 43 | tre_before_val=30.364, tre_after_val=30.271, elapsed time: 1.45 sec.
# 43 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_43_30.271.pth
# 44 | loss=6.062561
# 44 | tre_before_train=6.498, tre_after_train=6.420, elapsed time: 0.94 sec.
# 44 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.07 sec.
# 44 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_44_30.270.pth
# 45 | loss=6.045514
# 45 | tre_before_train=6.453, tre_after_train=6.367, elapsed time: 1.05 sec.
# 45 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.21 sec.
# 45 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_45_30.270.pth
# 46 | loss=6.024626
# 46 | tre_before_train=6.427, tre_after_train=6.345, elapsed time: 1.08 sec.
# 46 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.24 sec.
# 46 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_46_30.270.pth
# 47 | loss=6.062389
# 47 | tre_before_train=6.483, tre_after_train=6.401, elapsed time: 1.18 sec.
# 47 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.47 sec.
# 47 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_47_30.270.pth
# 48 | loss=6.109441
# 48 | tre_before_train=6.543, tre_after_train=6.475, elapsed time: 1.09 sec.
# 48 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.21 sec.
# 48 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_48_30.270.pth
# 49 | loss=6.103976
# 49 | tre_before_train=6.544, tre_after_train=6.469, elapsed time: 1.45 sec.
# 49 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.64 sec.
# 49 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_49_30.270.pth
# 50 | loss=6.106444
# 50 | tre_before_train=6.555, tre_after_train=6.491, elapsed time: 1.54 sec.
# 50 | tre_before_val=30.364, tre_after_val=30.270, elapsed time: 1.68 sec.
# 50 | Saving best TRE model: Autoencoder_kpt_loss_best_tre_50_30.270.pth

# %%
# log_val_tre = [x.item() for x in log_val_tre]
fig, axs = plt.subplots(1, 4, figsize=(15, 5))
axs[0].plot(log_train_loss)
axs[0].title.set_text("Autoencoder train_loss")
axs[1].plot(log_val_loss)
axs[1].title.set_text("Autoencoder val_loss")
axs[2].plot(log_train_tre)
axs[2].title.set_text("Autoencoder train_tre")
axs[3].plot(log_val_tre)
axs[3].title.set_text("Autoencoder val_tre")
plt.show()

# %%
load_pretrained_model_weights = False
if load_pretrained_model_weights:
    dir_load = dir_save  # folder where network weights are stored
    # instantiate warp layer
    warp_layer = Warp()
    # instantiate model
    model = VNet(spatial_dims=3, in_channels=2, out_channels=3, act=('elu', {'inplace': True}), 
             dropout_prob=0.2, dropout_prob_down=0.5, dropout_prob_up=(0.5, 0.5), dropout_dim=3, bias=False)
    # load model weights
    filename_best_model = glob.glob(os.path.join(dir_load, "Autoencoder_kpt_loss_best_tre*"))[0]
    model.load_state_dict(torch.load(filename_best_model))
    # to GPU
    model.to(device)

set_determinism(seed=1)
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1, shuffle=True)
check_data = first(check_loader)

# Forward pass
model.eval()
with torch.no_grad():
    ddf_image, ddf_keypoints, pred_image = forward(
            check_data["fixed_image"],
            check_data["moving_image"],
            check_data["fixed_landmarks"],
            model,
            warp_layer,
        )
        
        
def overlay_img(img1, img2, slice_idx, ax, title=None):
    ax.imshow(1 - img1[:, :, slice_idx], cmap="Blues", origin="lower")
    ax.imshow(1 - img2[:, :, slice_idx], cmap="Oranges", origin="lower", alpha=0.5)
    if title is not None:
        ax.set_title(title)  # Use set_title instead of title.set_text

# Image and label visualization
fixed_image = check_data["fixed_image"][0][0].permute(1, 0, 2)
moving_image = check_data["moving_image"][0][0].permute(1, 0, 2)
pred_image = pred_image[0][0].permute(1, 0, 2)

# Pointcloud visualization
fixed_keypoints = check_data["fixed_landmarks"][0]
moving_keypoints = check_data["moving_landmarks"][0]
moved_keypoints = fixed_keypoints + ddf_keypoints[0]

# Plot images and pointclouds
fig, axs = plt.subplots(2, 2, figsize=(10, 12)) 

# Image visualizations
slice_idx = int(target_res[0] * 95.0 / 224) 
overlay_img(fixed_image, moving_image, slice_idx, axs[0, 0], "Before registration")
overlay_img(fixed_image, pred_image, slice_idx, axs[0, 1], "After registration using Autoencoder")

# Pointcloud visualizations
ax = fig.add_subplot(2, 2, 3, projection="3d")
ax.scatter(fixed_keypoints[:, 0], fixed_keypoints[:, 1], fixed_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("Before registration")

ax = fig.add_subplot(2, 2, 4, projection="3d")
ax.scatter(moved_keypoints[:, 0], moved_keypoints[:, 1], moved_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("After registration using Autoencoder")

# Set axis off for image visualizations
for ax in axs[:, :].flat:
    ax.set_axis_off()

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Compute predicted TRE for validation dataset
_, predicted_tre_val = compute_tre_for_dataset(model, val_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_val = pd.DataFrame({
    #"Case": range(1, len(predicted_tre_val) + 1),
    "Case": 4,
    "Autoencoder Predicted TRE (Validation)": predicted_tre_val,
})

# Compute predicted TRE for training dataset
_, predicted_tre_train = compute_tre_for_dataset(model, train_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_train = pd.DataFrame({
    "Case": range(1, len(predicted_tre_train) + 1),
    "Autoencoder Predicted TRE (Training)": predicted_tre_train
})

# Display the combined results
print(df_results_train)
print(df_results_val)
# Out:
#    Case Autoencoder Predicted TRE (Training)
# 0     1                   metatensor(0.5788)
# 1     2                   metatensor(0.5662)
# 2     3                   metatensor(0.5765)
#    Case Autoencoder Predicted TRE (Validation)
# 0     4                     metatensor(0.5530)

# %% [markdown]
# HighResNet

# %%
from monai.networks.nets import HighResNet

# Model
model = HighResNet(spatial_dims=3, in_channels=2, out_channels=3, norm_type=('batch', {'affine': True}), acti_type=('relu', {'inplace': True}), dropout_prob=0.0, bias=False, 
                   layer_params=({'kernel_size': 3, 'n_features': 16, 'name': 'conv_0'}, {'kernels': (3, 3), 'n_features': 16, 'name': 'res_1', 'repeat': 3}, {'kernels': (3, 3), 'n_features': 32, 'name': 'res_2', 'repeat': 3}, {'kernels': (3, 3), 'n_features': 64, 'name': 'res_3', 'repeat': 3}, {'kernel_size': 1, 'n_features': 80, 'name': 'conv_1'}, {'kernel_size': 1, 'name': 'conv_2'}), channel_matching= 'pad')
warp_layer = Warp()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=max_epochs)

# %%
# Tensorboard
if do_save:
    writer = SummaryWriter(log_dir=dir_save)

# Training loop
val_interval = 1
best_eval_tre = float("inf")
log_train_loss = []
log_train_tre = []
log_val_tre = []
log_val_loss = []

pth_best_tre, pth_latest = "", ""

for epoch in range(max_epochs):
    # ==============================================
    # Train
    # ==============================================
    t0_train = time.time()
    model.train()

    epoch_loss, n_steps, tre_before, tre_after = 0, 0, 0, 0
    for batch_data in train_loader:
        # Get data
        fixed_image = batch_data["fixed_image"]
        moving_image = batch_data["moving_image"]
        fixed_keypoints = batch_data["fixed_landmarks"]
        moving_keypoints = batch_data["moving_landmarks"]
        n_steps += 1
        # Forward pass and loss
        optimizer.zero_grad()
        ddf_image, ddf_keypoints, pred_image = forward(
            fixed_image, moving_image, fixed_keypoints, model, warp_layer
        )
        loss = loss_fun(
            fixed_image,
            pred_image,
            fixed_keypoints + ddf_keypoints,
            moving_keypoints,
            ddf_image,
            lam_t,
            lam_m,
            lam_r,
        )
        # Optimise
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        # TRE before (voxel space)
        tre_before += tre(fixed_keypoints, moving_keypoints, vx = vx)
        tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx = vx)

    # Scheduler step
    lr_scheduler.step()
    # Loss
    epoch_loss /= n_steps
    tre_before /= n_steps
    tre_after /= n_steps
    log_train_tre.append(tre_after.item())
    log_train_loss.append(epoch_loss)
    if do_save:
        writer.add_scalar("train_loss", epoch_loss, epoch)
    print(f"{epoch + 1} | loss={epoch_loss:.6f}")

    # Mean TRE
    tre_before /= n_steps
    tre_after /= n_steps
    print(
            f"{epoch + 1} | tre_before_train={tre_before:.3f}, tre_after_train={tre_after:.3f}, elapsed time: {time.time()-t0_train:.2f} sec."
    )

    # ==============================================
    # Eval
    # ==============================================
    if (epoch + 1) % val_interval == 0:
        t0_eval = time.time()
        model.eval()

        val_epoch_loss , n_steps, tre_before, tre_after = 0, 0, 0, 0
        with torch.no_grad():
            for batch_data in val_loader:
                # Get data
                fixed_image = batch_data["fixed_image"]
                moving_image = batch_data["moving_image"]
                fixed_keypoints = batch_data["fixed_landmarks"]
                moving_keypoints = batch_data["moving_landmarks"]
                n_steps += 1

                # Infer
                ddf_image, ddf_keypoints, pred_image = forward(
                    fixed_image, moving_image, fixed_keypoints, model, warp_layer
                )

                # Loss for validation
                val_loss = loss_fun(
                    fixed_image,
                    pred_image,
                    fixed_keypoints + ddf_keypoints,
                    moving_keypoints,
                    ddf_image,
                    lam_t,
                    lam_m,
                    lam_r,
                )
                val_epoch_loss += val_loss.item()

                # TRE

                tre_before += tre(fixed_keypoints , moving_keypoints, vx=vx)
                tre_after += tre(fixed_keypoints + ddf_keypoints, moving_keypoints, vx=vx)

        # Mean TRE
        tre_before /= n_steps
        tre_after /= n_steps
        val_epoch_loss /= n_steps
        log_val_loss.append(val_epoch_loss)
        log_val_tre.append(tre_after.item())
        if do_save:
            writer.add_scalar("val_tre", tre_after, epoch)
       

        print(
            f"{epoch + 1} | tre_before_val={tre_before:.3f}, tre_after_val={tre_after:.3f}, elapsed time: {time.time() - t0_train:.2f} sec."
            )


        if tre_after < best_eval_tre:
            best_eval_tre = tre_after
            if do_save:
                # Save best model based on TRE
                if pth_best_tre != "":
                    os.remove(os.path.join(dir_save, pth_best_tre))
                pth_best_tre = f"HighResnet_kpt_loss_best_tre_{epoch + 1}_{best_eval_tre:.3f}.pth"
                torch.save(model.state_dict(), os.path.join(dir_save, pth_best_tre))
                print(f"{epoch + 1} | Saving best TRE model: {pth_best_tre}")

        if do_save:
            # Save latest model
            if pth_latest != "":
                os.remove(os.path.join(dir_save, pth_latest))
            pth_latest = "HighResnet_kpt_loss_latest.pth"
            torch.save(model.state_dict(), os.path.join(dir_save, pth_latest))
# Out:
# 1 | loss=5.748652
# 1 | tre_before_train=6.485, tre_after_train=6.151, elapsed time: 231.29 sec.
# 1 | tre_before_val=30.364, tre_after_val=30.403, elapsed time: 240.83 sec.
# 1 | Saving best TRE model: HighResnet_kpt_loss_best_tre_1_30.403.pth
# 2 | loss=5.010546
# 2 | tre_before_train=6.504, tre_after_train=5.405, elapsed time: 154.26 sec.
# 2 | tre_before_val=30.364, tre_after_val=30.448, elapsed time: 164.71 sec.
# 3 | loss=4.653946
# 3 | tre_before_train=6.448, tre_after_train=5.012, elapsed time: 160.83 sec.
# 3 | tre_before_val=30.364, tre_after_val=30.369, elapsed time: 171.12 sec.
# 3 | Saving best TRE model: HighResnet_kpt_loss_best_tre_3_30.369.pth
# 4 | loss=4.753556
# 4 | tre_before_train=6.508, tre_after_train=5.123, elapsed time: 174.83 sec.
# 4 | tre_before_val=30.364, tre_after_val=30.249, elapsed time: 184.86 sec.
# 4 | Saving best TRE model: HighResnet_kpt_loss_best_tre_4_30.249.pth
# 5 | loss=4.781235
# 5 | tre_before_train=6.501, tre_after_train=5.208, elapsed time: 167.01 sec.
# 5 | tre_before_val=30.364, tre_after_val=30.134, elapsed time: 177.05 sec.
# 5 | Saving best TRE model: HighResnet_kpt_loss_best_tre_5_30.134.pth
# 6 | loss=4.442621
# 6 | tre_before_train=6.405, tre_after_train=4.803, elapsed time: 159.68 sec.
# 6 | tre_before_val=30.364, tre_after_val=29.906, elapsed time: 170.23 sec.
# 6 | Saving best TRE model: HighResnet_kpt_loss_best_tre_6_29.906.pth
# 7 | loss=4.650532
# 7 | tre_before_train=6.446, tre_after_train=5.027, elapsed time: 158.99 sec.
# 7 | tre_before_val=30.364, tre_after_val=29.671, elapsed time: 169.20 sec.
# 7 | Saving best TRE model: HighResnet_kpt_loss_best_tre_7_29.671.pth
# 8 | loss=4.768737
# 8 | tre_before_train=6.497, tre_after_train=5.161, elapsed time: 158.11 sec.
# 8 | tre_before_val=30.364, tre_after_val=29.442, elapsed time: 168.21 sec.
# 8 | Saving best TRE model: HighResnet_kpt_loss_best_tre_8_29.442.pth
# 9 | loss=4.628874
# 9 | tre_before_train=6.492, tre_after_train=5.009, elapsed time: 162.09 sec.
# 9 | tre_before_val=30.364, tre_after_val=29.325, elapsed time: 172.59 sec.
# 9 | Saving best TRE model: HighResnet_kpt_loss_best_tre_9_29.325.pth
# 10 | loss=4.380244
# 10 | tre_before_train=6.415, tre_after_train=4.737, elapsed time: 189.18 sec.
# 10 | tre_before_val=30.364, tre_after_val=29.129, elapsed time: 201.02 sec.
# 10 | Saving best TRE model: HighResnet_kpt_loss_best_tre_10_29.129.pth
# 11 | loss=4.548864
# 11 | tre_before_train=6.502, tre_after_train=4.950, elapsed time: 171.89 sec.
# 11 | tre_before_val=30.364, tre_after_val=28.967, elapsed time: 182.93 sec.
# 11 | Saving best TRE model: HighResnet_kpt_loss_best_tre_11_28.967.pth
# 12 | loss=4.471276
# 12 | tre_before_train=6.484, tre_after_train=4.872, elapsed time: 165.72 sec.
# 12 | tre_before_val=30.364, tre_after_val=28.908, elapsed time: 176.52 sec.
# 12 | Saving best TRE model: HighResnet_kpt_loss_best_tre_12_28.908.pth
# 13 | loss=4.342970
# 13 | tre_before_train=6.457, tre_after_train=4.706, elapsed time: 166.22 sec.
# 13 | tre_before_val=30.364, tre_after_val=28.535, elapsed time: 176.79 sec.
# 13 | Saving best TRE model: HighResnet_kpt_loss_best_tre_13_28.535.pth
# 14 | loss=4.421054
# 14 | tre_before_train=6.475, tre_after_train=4.819, elapsed time: 165.21 sec.
# 14 | tre_before_val=30.364, tre_after_val=28.292, elapsed time: 176.05 sec.
# 14 | Saving best TRE model: HighResnet_kpt_loss_best_tre_14_28.292.pth
# 15 | loss=4.300568
# 15 | tre_before_train=6.459, tre_after_train=4.665, elapsed time: 161.01 sec.
# 15 | tre_before_val=30.364, tre_after_val=28.187, elapsed time: 171.25 sec.
# 15 | Saving best TRE model: HighResnet_kpt_loss_best_tre_15_28.187.pth
# 16 | loss=4.253301
# 16 | tre_before_train=6.457, tre_after_train=4.600, elapsed time: 160.04 sec.
# 16 | tre_before_val=30.364, tre_after_val=28.821, elapsed time: 170.14 sec.
# 17 | loss=4.464361
# 17 | tre_before_train=6.519, tre_after_train=4.844, elapsed time: 176.71 sec.
# 17 | tre_before_val=30.364, tre_after_val=28.712, elapsed time: 190.80 sec.
# 18 | loss=4.328013
# 18 | tre_before_train=6.527, tre_after_train=4.700, elapsed time: 185.77 sec.
# 18 | tre_before_val=30.364, tre_after_val=27.368, elapsed time: 197.32 sec.
# 18 | Saving best TRE model: HighResnet_kpt_loss_best_tre_18_27.368.pth
# 19 | loss=4.501119
# 19 | tre_before_train=6.510, tre_after_train=4.902, elapsed time: 164.72 sec.
# 19 | tre_before_val=30.364, tre_after_val=27.289, elapsed time: 175.29 sec.
# 19 | Saving best TRE model: HighResnet_kpt_loss_best_tre_19_27.289.pth
# 20 | loss=4.197916
# 20 | tre_before_train=6.436, tre_after_train=4.556, elapsed time: 172.56 sec.
# 20 | tre_before_val=30.364, tre_after_val=27.700, elapsed time: 183.38 sec.
# 21 | loss=4.251743
# 21 | tre_before_train=6.459, tre_after_train=4.632, elapsed time: 188.04 sec.
# 21 | tre_before_val=30.364, tre_after_val=28.116, elapsed time: 199.77 sec.
# 22 | loss=4.249125
# 22 | tre_before_train=6.471, tre_after_train=4.601, elapsed time: 193.38 sec.
# 22 | tre_before_val=30.364, tre_after_val=28.526, elapsed time: 204.66 sec.
# 23 | loss=4.273108
# 23 | tre_before_train=6.478, tre_after_train=4.655, elapsed time: 168.94 sec.
# 23 | tre_before_val=30.364, tre_after_val=28.341, elapsed time: 179.67 sec.
# 24 | loss=4.249676
# 24 | tre_before_train=6.564, tre_after_train=4.615, elapsed time: 164.99 sec.
# 24 | tre_before_val=30.364, tre_after_val=27.659, elapsed time: 175.32 sec.
# 25 | loss=4.071517
# 25 | tre_before_train=6.439, tre_after_train=4.434, elapsed time: 164.46 sec.
# 25 | tre_before_val=30.364, tre_after_val=27.280, elapsed time: 174.74 sec.
# 25 | Saving best TRE model: HighResnet_kpt_loss_best_tre_25_27.280.pth
# 26 | loss=4.025717
# 26 | tre_before_train=6.439, tre_after_train=4.369, elapsed time: 165.33 sec.
# 26 | tre_before_val=30.364, tre_after_val=27.706, elapsed time: 176.07 sec.
# 27 | loss=4.417501
# 27 | tre_before_train=6.605, tre_after_train=4.834, elapsed time: 180.61 sec.
# 27 | tre_before_val=30.364, tre_after_val=28.220, elapsed time: 192.83 sec.
# 28 | loss=4.128713
# 28 | tre_before_train=6.446, tre_after_train=4.506, elapsed time: 184.63 sec.
# 28 | tre_before_val=30.364, tre_after_val=28.221, elapsed time: 194.32 sec.
# 29 | loss=4.116859
# 29 | tre_before_train=6.462, tre_after_train=4.480, elapsed time: 159.44 sec.
# 29 | tre_before_val=30.364, tre_after_val=28.030, elapsed time: 168.24 sec.
# 30 | loss=4.289769
# 30 | tre_before_train=6.523, tre_after_train=4.674, elapsed time: 148.28 sec.
# 30 | tre_before_val=30.364, tre_after_val=27.710, elapsed time: 158.30 sec.
# 31 | loss=4.284299
# 31 | tre_before_train=6.522, tre_after_train=4.678, elapsed time: 147.04 sec.
# 31 | tre_before_val=30.364, tre_after_val=27.578, elapsed time: 156.37 sec.
# 32 | loss=4.095749
# 32 | tre_before_train=6.448, tre_after_train=4.449, elapsed time: 143.58 sec.
# 32 | tre_before_val=30.364, tre_after_val=27.451, elapsed time: 152.21 sec.
# 33 | loss=4.236079
# 33 | tre_before_train=6.557, tre_after_train=4.629, elapsed time: 146.35 sec.
# 33 | tre_before_val=30.364, tre_after_val=27.809, elapsed time: 155.45 sec.
# 34 | loss=3.943436
# 34 | tre_before_train=6.442, tre_after_train=4.292, elapsed time: 145.78 sec.
# 34 | tre_before_val=30.364, tre_after_val=27.841, elapsed time: 154.87 sec.
# 35 | loss=4.023525
# 35 | tre_before_train=6.484, tre_after_train=4.362, elapsed time: 143.66 sec.
# 35 | tre_before_val=30.364, tre_after_val=27.965, elapsed time: 152.36 sec.
# 36 | loss=4.106924
# 36 | tre_before_train=6.470, tre_after_train=4.492, elapsed time: 152.22 sec.
# 36 | tre_before_val=30.364, tre_after_val=28.146, elapsed time: 161.34 sec.
# 37 | loss=3.878840
# 37 | tre_before_train=6.471, tre_after_train=4.232, elapsed time: 145.31 sec.
# 37 | tre_before_val=30.364, tre_after_val=28.357, elapsed time: 154.72 sec.
# 38 | loss=4.105288
# 38 | tre_before_train=6.469, tre_after_train=4.517, elapsed time: 144.99 sec.
# 38 | tre_before_val=30.364, tre_after_val=28.295, elapsed time: 153.65 sec.
# 39 | loss=3.783627
# 39 | tre_before_train=6.423, tre_after_train=4.120, elapsed time: 133.92 sec.
# 39 | tre_before_val=30.364, tre_after_val=28.033, elapsed time: 143.16 sec.
# 40 | loss=3.865759
# 40 | tre_before_train=6.484, tre_after_train=4.221, elapsed time: 132.98 sec.
# 40 | tre_before_val=30.364, tre_after_val=27.752, elapsed time: 142.35 sec.
# 41 | loss=3.919638
# 41 | tre_before_train=6.463, tre_after_train=4.261, elapsed time: 154.32 sec.
# 41 | tre_before_val=30.364, tre_after_val=27.655, elapsed time: 163.58 sec.
# 42 | loss=3.789062
# 42 | tre_before_train=6.436, tre_after_train=4.134, elapsed time: 148.44 sec.
# 42 | tre_before_val=30.364, tre_after_val=27.792, elapsed time: 157.59 sec.
# 43 | loss=3.971869
# 43 | tre_before_train=6.512, tre_after_train=4.317, elapsed time: 144.47 sec.
# 43 | tre_before_val=30.364, tre_after_val=27.991, elapsed time: 153.15 sec.
# 44 | loss=3.791138
# 44 | tre_before_train=6.431, tre_after_train=4.139, elapsed time: 140.67 sec.
# 44 | tre_before_val=30.364, tre_after_val=28.170, elapsed time: 150.51 sec.
# 45 | loss=3.988118
# 45 | tre_before_train=6.493, tre_after_train=4.358, elapsed time: 142.82 sec.
# 45 | tre_before_val=30.364, tre_after_val=28.193, elapsed time: 151.89 sec.
# 46 | loss=3.902386
# 46 | tre_before_train=6.493, tre_after_train=4.260, elapsed time: 145.24 sec.
# 46 | tre_before_val=30.364, tre_after_val=28.194, elapsed time: 154.29 sec.
# 47 | loss=4.086369
# 47 | tre_before_train=6.508, tre_after_train=4.486, elapsed time: 137.93 sec.
# 47 | tre_before_val=30.364, tre_after_val=28.090, elapsed time: 146.66 sec.
# 48 | loss=4.103682
# 48 | tre_before_train=6.517, tre_after_train=4.511, elapsed time: 146.33 sec.
# 48 | tre_before_val=30.364, tre_after_val=28.023, elapsed time: 155.95 sec.
# 49 | loss=3.927406
# 49 | tre_before_train=6.486, tre_after_train=4.273, elapsed time: 155.12 sec.
# 49 | tre_before_val=30.364, tre_after_val=28.041, elapsed time: 165.61 sec.
# 50 | loss=4.186153
# 50 | tre_before_train=6.513, tre_after_train=4.602, elapsed time: 159.71 sec.
# 50 | tre_before_val=30.364, tre_after_val=28.059, elapsed time: 170.00 sec.

# %%
# log_val_tre = [x.item() for x in log_val_tre]
fig, axs = plt.subplots(1, 4, figsize=(15, 5))
axs[0].plot(log_train_loss)
axs[0].title.set_text("HighResnet train_loss")
axs[1].plot(log_val_loss)
axs[1].title.set_text("HighResnet val_loss")
axs[2].plot(log_train_tre)
axs[2].title.set_text("HighResnet train_tre")
axs[3].plot(log_val_tre)
axs[3].title.set_text("HighResnet val_tre")
plt.show()

# %%
load_pretrained_model_weights = False
if load_pretrained_model_weights:
    dir_load = dir_save  # folder where network weights are stored
    # instantiate warp layer
    warp_layer = Warp()
    # instantiate model
    model = VNet(spatial_dims=3, in_channels=2, out_channels=3, act=('elu', {'inplace': True}), 
             dropout_prob=0.2, dropout_prob_down=0.5, dropout_prob_up=(0.5, 0.5), dropout_dim=3, bias=False)
    # load model weights
    filename_best_model = glob.glob(os.path.join(dir_load, "HighResnet_kpt_loss_best_tre*"))[0]
    model.load_state_dict(torch.load(filename_best_model))
    # to GPU
    model.to(device)

set_determinism(seed=1)
check_ds = Dataset(data=val_files, transform=val_transforms)
check_loader = DataLoader(check_ds, batch_size=1, shuffle=True)
check_data = first(check_loader)

# Forward pass
model.eval()
with torch.no_grad():
    ddf_image, ddf_keypoints, pred_image = forward(
            check_data["fixed_image"],
            check_data["moving_image"],
            check_data["fixed_landmarks"],
            model,
            warp_layer,
        )
        
        
def overlay_img(img1, img2, slice_idx, ax, title=None):
    ax.imshow(1 - img1[:, :, slice_idx], cmap="Blues", origin="lower")
    ax.imshow(1 - img2[:, :, slice_idx], cmap="Oranges", origin="lower", alpha=0.5)
    if title is not None:
        ax.set_title(title)  # Use set_title instead of title.set_text

# Image and label visualization
fixed_image = check_data["fixed_image"][0][0].permute(1, 0, 2)
moving_image = check_data["moving_image"][0][0].permute(1, 0, 2)
pred_image = pred_image[0][0].permute(1, 0, 2)

# Pointcloud visualization
fixed_keypoints = check_data["fixed_landmarks"][0]
moving_keypoints = check_data["moving_landmarks"][0]
moved_keypoints = fixed_keypoints + ddf_keypoints[0]

# Plot images and pointclouds
fig, axs = plt.subplots(2, 2, figsize=(10, 12)) 

# Image visualizations
slice_idx = int(target_res[0] * 95.0 / 224) 
overlay_img(fixed_image, moving_image, slice_idx, axs[0, 0], "Before registration")
overlay_img(fixed_image, pred_image, slice_idx, axs[0, 1], "After registration using HighResnet")

# Pointcloud visualizations
ax = fig.add_subplot(2, 2, 3, projection="3d")
ax.scatter(fixed_keypoints[:, 0], fixed_keypoints[:, 1], fixed_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("Before registration")

ax = fig.add_subplot(2, 2, 4, projection="3d")
ax.scatter(moved_keypoints[:, 0], moved_keypoints[:, 1], moved_keypoints[:, 2], s=2.0, marker="o", color="blue")
ax.scatter(moving_keypoints[:, 0], moving_keypoints[:, 1], moving_keypoints[:, 2], s=2.0, marker="o", color="red")
ax.view_init(-10, 80)
ax.set_aspect("auto")
ax.set_title("After registration using HighResnet")

# Set axis off for image visualizations
for ax in axs[:, :].flat:
    ax.set_axis_off()

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Compute predicted TRE for validation dataset
_, predicted_tre_val = compute_tre_for_dataset(model, val_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_val = pd.DataFrame({
    #"Case": range(1, len(predicted_tre_val) + 1),
    "Case": 4,
    "HighResnet Predicted TRE (Val)": predicted_tre_val,
})

# Compute predicted TRE for training dataset
_, predicted_tre_train = compute_tre_for_dataset(model, train_loader, warp_layer, vx=vx)

# Display the results in a table
df_results_train = pd.DataFrame({
    "Case": range(1, len(predicted_tre_train) + 1),
    "HighResnet Predicted TRE (Train)": predicted_tre_train
})

# Display the combined results
print(df_results_train)
print(df_results_val)
# Out:
#    Case HighResnet Predicted TRE (Train)
# 0     1               metatensor(8.2021)
# 1     2              metatensor(11.3182)
# 2     3               metatensor(3.9731)
#    Case HighResnet Predicted TRE (Val)
# 0     4             metatensor(6.1212)
